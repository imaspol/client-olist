# %% [markdown]
# #### Auteur: Irina Maslowski

# %% [markdown]
# ### Projet N° 4 Segmentez des clients d'un site e-commerce

# %% [markdown]
# #### Données: [Brazilian E-Commerce Public Dataset by Olist. 100,000 Orders with product, customer and reviews info](https://www.kaggle.com/olistbr/brazilian-ecommerce)
# années: 2016 - 2018

# %% [markdown]
# ![Le schéma des données](scheme.png)

# %% [markdown]
# ## Taches:
# 1. utiliserez donc des méthodes non supervisées pour regrouper ensemble des clients de profils similaires
# 2. créer les meilleures features pour les exploiter à partir de données dans notre disposition
# **Cahier des charges** :
# 1. La segmentation proposée doit être exploitable et facile d’utilisation pour l’équipe marketing.
# 2. Vous évaluerez la fréquence à laquelle la segmentation doit être mise à jour, afin de pouvoir effectuer un devis de contrat de maintenance.
# 3. Le code fourni doit respecter la convention PEP8, pour être utilisable par Olist.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as st
# EXEMPLE sur http://www.python-simple.com/python-statsmodels/statsmodels-anova.php
import statsmodels.formula.api
import statsmodels.api

# %%
# certains services de géolocalisation sont limités et payant au delà de certain nombre d'appel
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

# %% [markdown]
# ## Sommaire:
# * [Import des données](#first-bullet)
# * [Etape 1 de merge](#merge1)
# * [Etape 2 de merge](#merge2)
#     * [Imputation de données de géolocalisation manquantes](#geo_fillin)
# * [Etape 3 de merge](#merge3)
# * [Etape 4 de merge](#merge4)
# * [Etape 5 de merge](#merge5)
# * [Etape 6 de merge](#merge6)
#     * [Imputation d'une traduction manqaunte](#trad_prod)
# * [Etape 7 de merge](#merge7)
# * [Etape 8 de merge](#merge8)
# * [Etape 9 de merge](#merge9)

# %% [markdown]
# # Import des données <a class="anchor" id="first-bullet"></a>

# %%
# olist_customers_dataset
df_olist_customers = pd.read_csv('D:/OpenClassroomsProjectData/e-commerce/olist_customers_dataset.csv', encoding='utf-8', low_memory=False)
df_olist_customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
df_olist_customers.shape
# Out:
# (99441, 5)

# %%
df_olist_customers.duplicated(subset=['customer_id']).sum()
# Out:
# 0

# %%
df_olist_customers.duplicated(subset=['customer_unique_id']).sum()
# Out:
# 3345

# %%
df_olist_customers[df_olist_customers.duplicated(subset=['customer_unique_id'], keep=False) == True][['customer_unique_id', 'customer_id']].sort_values(by=['customer_unique_id'])
# Out:
#                      customer_unique_id                       customer_id
# 35608  00172711b30d52eea8b313a7f2cced02  24b0e2bd287e47d54d193e7bbb51103f
# 19299  00172711b30d52eea8b313a7f2cced02  1afe8a9c67eec3516c09a8bdcc539090
# 20023  004288347e5e88a27ded2bb23747066c  1b4a75b3478138e99902678254b260f4
# 22066  004288347e5e88a27ded2bb23747066c  f6efe5d5c7b85e12355f9d5c3db46da2
# 72451  004b45ec5c64187465168251cd1c9c2f  49cf243e0d353cd418ca77868e24a670
# ...                                 ...                               ...
# 75057  ff922bdd6bafcdf99cb90d7f39cea5b3  1ae563fdfa500d150be6578066d83998
# 27992  ff922bdd6bafcdf99cb90d7f39cea5b3  bec0bf00ac5bee64ce8ef5283051a70c
# 79859  ff922bdd6bafcdf99cb90d7f39cea5b3  d064be88116eb8b958727aec4cf56a59
# 64323  ffe254cc039740e17dd15a5305035928  4b231c90751c27521f7ee27ed2dc3b8f
# 12133  ffe254cc039740e17dd15a5305035928  0088395699ea0fcd459bfbef084997db
#
# [6342 rows x 2 columns]

# %%
df_olist_customers.groupby('customer_id').agg({'customer_unique_id':'count'}).max()
# Out:
# customer_unique_id    1
# dtype: int64

# %%
df_olist_customers.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
# olist_geolocation_dataset
df_olist_geolocation = pd.read_csv('D:/OpenClassroomsProjectData/e-commerce/olist_geolocation_dataset.csv', encoding='utf-8', low_memory=False)
df_olist_geolocation.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
df_olist_geolocation[df_olist_geolocation['geolocation_zip_code_prefix'] == 14409]
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 334422                        14409       -20.509897       -47.397866
# 334449                        14409       -20.497396       -47.399241
# 334459                        14409       -20.510459       -47.399553
# 334462                        14409       -20.480940       -47.394161
# 334463                        14409       -20.515413       -47.398194
# ...                             ...              ...              ...
# 336625                        14409       -20.483960       -47.403324
# 336650                        14409       -20.483960       -47.403324
# 336653                        14409       -20.487255       -47.405925
# 336657                        14409       -20.510459       -47.399553
# 336670                        14409       -20.500253       -47.400367
#
#        geolocation_city geolocation_state
# 334422           franca                SP
# 334449           franca                SP
# 334459           franca                SP
# 334462           franca                SP
# 334463           franca                SP
# ...                 ...               ...
# 336625           franca                SP
# 336650           franca                SP
# 336653           franca                SP
# 336657           franca                SP
# 336670           franca                SP
#
# [147 rows x 5 columns]

# %%
df_olist_geolocation[df_olist_geolocation['geolocation_zip_code_prefix'] == 14409]['geolocation_lat'].max()
# Out:
# -20.4688485

# %%
df_olist_geolocation[df_olist_geolocation['geolocation_zip_code_prefix'] == 14409]['geolocation_lat'].min()
# Out:
# -20.519565436705047

# %%
df_olist_geolocation[df_olist_geolocation['geolocation_zip_code_prefix'] == 14409]['geolocation_lat'].mean()
# Out:
# -20.498488755380297

# %%
df_olist_geolocation[df_olist_geolocation['geolocation_zip_code_prefix'] == 14409]['geolocation_lat'].median()
# Out:
# -20.502070116372256

# %% [markdown]
# les coordonnées sont suffisement proche pour qu'on puisse laisse une coordonnées médiane pour un zip code

# %%
df_olist_geolocation.shape
# Out:
# (1000163, 5)

# %% [markdown]
# #### suppression des doublons dans le fichiers des coordonnées

# %%
df_olist_geolocation.duplicated().sum()
# Out:
# 261831

# %%
df_geo_without_duplicates = df_olist_geolocation.drop_duplicates()

# %%
df_geo_without_duplicates
# Out:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                               1037       -23.545621       -46.639292
# 1                               1046       -23.546081       -46.644820
# 2                               1046       -23.546129       -46.642951
# 3                               1041       -23.544392       -46.639499
# 4                               1035       -23.541578       -46.641607
# ...                              ...              ...              ...
# 1000155                        99965       -28.180655       -52.034367
# 1000156                        99950       -28.072188       -52.011272
# 1000157                        99950       -28.068864       -52.012964
# 1000158                        99950       -28.068639       -52.010705
# 1000161                        99980       -28.388932       -51.846871
#
#         geolocation_city geolocation_state
# 0              sao paulo                SP
# 1              sao paulo                SP
# 2              sao paulo                SP
# 3              sao paulo                SP
# 4              sao paulo                SP
# ...                  ...               ...
# 1000155       agua santa                RS
# 1000156         tapejara                RS
# 1000157         tapejara                RS
# 1000158         tapejara                RS
# 1000161  david canabarro                RS
#
# [738332 rows x 5 columns]

# %%
df_geo_without_duplicates[df_geo_without_duplicates['geolocation_zip_code_prefix'] == 1046]['geolocation_lat'].median()
# Out:
# -23.54574166250217

# %%
df_geo_without_duplicates[df_geo_without_duplicates['geolocation_zip_code_prefix'] == 1046]['geolocation_lng'].median()
# Out:
# -46.643199191240036

# %%
df_geo_without_duplicates.duplicated(subset=['geolocation_zip_code_prefix']).sum()
# Out:
# 719317

# %% [markdown]
# Aggrégation de cellules de zip-code en choisissant la médiane des coordonnées

# %%
df_geo_agg = df_geo_without_duplicates.groupby('geolocation_zip_code_prefix').agg({
    'geolocation_lat':'median',
    'geolocation_lng':'median', 
    'geolocation_city': 'last',
    'geolocation_state': 'last'
}).reset_index()

# %%
df_geo_agg.duplicated(subset=['geolocation_zip_code_prefix']).sum()
# Out:
# 0

# %%
df_geo_agg
# Out:
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                             1001       -23.549951       -46.634027
# 1                             1002       -23.548228       -46.635247
# 2                             1003       -23.548977       -46.635313
# 3                             1004       -23.549550       -46.634771
# 4                             1005       -23.549763       -46.636100
# ...                            ...              ...              ...
# 19010                        99960       -27.953797       -52.029641
# 19011                        99965       -28.179542       -52.035551
# 19012                        99970       -28.343257       -51.875470
# 19013                        99980       -28.388342       -51.846871
# 19014                        99990       -28.329595       -51.769362
#
#       geolocation_city geolocation_state
# 0            são paulo                SP
# 1            são paulo                SP
# 2            sao paulo                SP
# 3            sao paulo                SP
# 4            sao paulo                SP
# ...                ...               ...
# 19010          charrua                RS
# 19011       agua santa                RS
# 19012          ciriaco                RS
# 19013  david canabarro                RS
# 19014        muliterno                RS
#
# [19015 rows x 5 columns]

# %%
# olist_order_items_dataset
df_olist_order_items = pd.read_csv('D:/OpenClassroomsProjectData/e-commerce/olist_order_items_dataset.csv', encoding='utf-8', low_memory=False)
df_olist_order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# 4  2017-02-13 13:57:51  199.90          18.14

# %%
df_olist_order_items.shape
# Out:
# (112650, 7)

# %%
df_olist_order_items.isna().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
# olist_order_payments_dataset
df_olist_order_payments = pd.read_csv('D:/OpenClassroomsProjectData/e-commerce/olist_order_payments_dataset.csv', encoding='utf-8', low_memory=False)
df_olist_order_payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
df_olist_order_payments.shape
# Out:
# (103886, 5)

# %%
df_olist_order_payments.isna().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
# olist_order_reviews_dataset
df_olist_order_reviews_dataset = pd.read_csv('D:/OpenClassroomsProjectData/e-commerce/olist_order_reviews_dataset.csv', encoding='utf-8', low_memory=False)
df_olist_order_reviews_dataset.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# 3              Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 4  Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
#
#   review_answer_timestamp
# 0     2018-01-18 21:46:59
# 1     2018-03-11 03:05:13
# 2     2018-02-18 14:36:24
# 3     2017-04-21 22:02:06
# 4     2018-03-02 10:26:53

# %%
df_olist_order_reviews_dataset.shape
# Out:
# (100000, 7)

# %%
df_olist_order_reviews_dataset.isna().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       88285
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
df_olist_order_reviews_dataset['contain_message'] = df_olist_order_reviews_dataset['review_comment_message'].notna()

# %%
df_olist_order_reviews_dataset.drop(['review_comment_message'], axis=1, inplace=True)

# %%
df_olist_order_reviews_dataset.drop(['review_comment_title'], axis=1, inplace=True)

# %%
df_olist_order_reviews_dataset.isna().sum()
# Out:
# review_id                  0
# order_id                   0
# review_score               0
# review_creation_date       0
# review_answer_timestamp    0
# contain_message            0
# dtype: int64

# %%
# olist_orders_dataset
df_olist_orders = pd.read_csv('D:/OpenClassroomsProjectData/e-commerce/olist_orders_dataset.csv', encoding='utf-8', low_memory=False)
df_olist_orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date
# 0           2017-10-18 00:00:00
# 1           2018-08-13 00:00:00
# 2           2018-09-04 00:00:00
# 3           2017-12-15 00:00:00
# 4           2018-02-26 00:00:00

# %%
df_olist_orders.shape
# Out:
# (99441, 8)

# %%
# olist_products_dataset
df_olist_products = pd.read_csv('D:/OpenClassroomsProjectData/e-commerce/olist_products_dataset.csv', encoding='utf-8', low_memory=False)
df_olist_products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0

# %%
df_olist_products.shape
# Out:
# (32951, 9)

# %%
df_olist_products.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
# olist_sellers_dataset
df_olist_sellers = pd.read_csv('D:/OpenClassroomsProjectData/e-commerce/olist_sellers_dataset.csv', encoding='utf-8', low_memory=False)
df_olist_sellers.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
df_olist_sellers.shape
# Out:
# (3095, 4)

# %%
df_olist_sellers.isna().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %%
# product_category_name_translation
df_product_category_name_translation = pd.read_csv('D:/OpenClassroomsProjectData/e-commerce/product_category_name_translation.csv', encoding='utf-8', low_memory=False)
df_product_category_name_translation.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
df_product_category_name_translation.shape
# Out:
# (71, 2)

# %%
df_product_category_name_translation.isna().sum()
# Out:
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %% [markdown]
# # Etape 1 de merge <a class="anchor" id="merge1"></a>

# %% [markdown]
# #### Merge de dataframe 'commandes' avec la dataframe 'clients'
# dataframe *df_olist_orders_customers*

# %%
df_olist_orders_customers = df_olist_orders.merge(df_olist_customers,  how='left', on='customer_id')
df_olist_orders_customers.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date                customer_unique_id  \
# 0           2017-10-18 00:00:00  7c396fd4830fd04220f754e42b4e5bff
# 1           2018-08-13 00:00:00  af07308b275d755c9edb36a90c618231
# 2           2018-09-04 00:00:00  3a653a41f6f9fc3d2a113cf8398680e8
# 3           2017-12-15 00:00:00  7c142cf63193a1473d2e66489a9ae977
# 4           2018-02-26 00:00:00  72632f0f9dd73dfee390c9b22eb56dd6
#
#    customer_zip_code_prefix            customer_city customer_state
# 0                      3149                sao paulo             SP
# 1                     47813                barreiras             BA
# 2                     75265               vianopolis             GO
# 3                     59296  sao goncalo do amarante             RN
# 4                      9195              santo andre             SP

# %% [markdown]
# #### Idées de feature engineering pour les commandes:
# temps de livraison<br>
# temps depuis la dernière commande

# %%
df_olist_orders_customers[df_olist_orders_customers['order_delivered_customer_date'].isna()][['order_delivered_customer_date','order_delivered_carrier_date', 'order_approved_at', 'order_status']]
# Out:
#       order_delivered_customer_date order_delivered_carrier_date  \
# 6                               NaN                          NaN
# 44                              NaN          2018-06-05 14:32:00
# 103                             NaN                          NaN
# 128                             NaN                          NaN
# 154                             NaN          2018-01-11 19:39:23
# ...                             ...                          ...
# 99283                           NaN                          NaN
# 99313                           NaN                          NaN
# 99347                           NaN                          NaN
# 99348                           NaN                          NaN
# 99415                           NaN                          NaN
#
#          order_approved_at order_status
# 6      2017-04-13 13:25:17     invoiced
# 44     2018-06-05 04:31:18      shipped
# 103    2018-08-07 06:15:14     invoiced
# 128    2017-09-03 14:30:09   processing
# 154    2018-01-11 02:32:30      shipped
# ...                    ...          ...
# 99283                  NaN     canceled
# 99313  2018-01-09 07:18:05   processing
# 99347                  NaN     canceled
# 99348  2017-08-28 15:44:47  unavailable
# 99415  2017-10-14 18:35:57  unavailable
#
# [2965 rows x 4 columns]

# %%
df_olist_orders_customers.shape
# Out:
# (99441, 12)

# %% [markdown]
# ![Le schéma des données](scheme_etape_1.png)

# %% [markdown]
# # Etape 2 de merge <a class="anchor" id="merge2"></a>

# %% [markdown]
# #### Merge des dataframes df_olist_orders_customers et df_geo_agg
# dataframe résultant ==> df_olist_orders_customers_geo

# %%
df_olist_orders_customers_geo = df_olist_orders_customers.merge(df_geo_agg, how='left', left_on='customer_zip_code_prefix', right_on='geolocation_zip_code_prefix')

# %%
df_ord_cust_geo = df_olist_orders_customers_geo.copy()

# %%
df_ord_cust_geo.shape
# Out:
# (99441, 17)

# %%
df_olist_orders_customers_geo.shape
# Out:
# (99441, 17)

# %%
df_olist_orders_customers_geo
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# 0        delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1        delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2        delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3        delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4        delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
# ...            ...                      ...                  ...
# 99436    delivered      2017-03-09 09:54:05  2017-03-09 09:54:05
# 99437    delivered      2018-02-06 12:58:58  2018-02-06 13:10:37
# 99438    delivered      2017-08-27 14:46:43  2017-08-27 15:04:16
# 99439    delivered      2018-01-08 21:28:27  2018-01-08 21:36:21
# 99440    delivered      2018-03-08 20:57:30  2018-03-09 11:20:28
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 0              2017-10-04 19:55:00           2017-10-10 21:25:13
# 1              2018-07-26 14:31:00           2018-08-07 15:27:45
# 2              2018-08-08 13:50:00           2018-08-17 18:06:29
# 3              2017-11-22 13:39:59           2017-12-02 00:28:42
# 4              2018-02-14 19:46:34           2018-02-16 18:17:02
# ...                            ...                           ...
# 99436          2017-03-10 11:18:03           2017-03-17 15:08:01
# 99437          2018-02-07 23:22:42           2018-02-28 17:37:56
# 99438          2017-08-28 20:52:26           2017-09-21 11:24:17
# 99439          2018-01-12 15:35:03           2018-01-25 23:32:54
# 99440          2018-03-09 22:11:59           2018-03-16 13:08:30
#
#       order_estimated_delivery_date                customer_unique_id  \
# 0               2017-10-18 00:00:00  7c396fd4830fd04220f754e42b4e5bff
# 1               2018-08-13 00:00:00  af07308b275d755c9edb36a90c618231
# 2               2018-09-04 00:00:00  3a653a41f6f9fc3d2a113cf8398680e8
# 3               2017-12-15 00:00:00  7c142cf63193a1473d2e66489a9ae977
# 4               2018-02-26 00:00:00  72632f0f9dd73dfee390c9b22eb56dd6
# ...                             ...                               ...
# 99436           2017-03-28 00:00:00  6359f309b166b0196dbf7ad2ac62bb5a
# 99437           2018-03-02 00:00:00  da62f9e57a76d978d02ab5362c509660
# 99438           2017-09-27 00:00:00  737520a9aad80b3fbbdad19b66b37b30
# 99439           2018-02-15 00:00:00  5097a5312c8b157bb7be58ae360ef43c
# 99440           2018-04-03 00:00:00  60350aa974b26ff12caad89e55993bd6
#
#        customer_zip_code_prefix            customer_city customer_state  \
# 0                          3149                sao paulo             SP
# 1                         47813                barreiras             BA
# 2                         75265               vianopolis             GO
# 3                         59296  sao goncalo do amarante             RN
# 4                          9195              santo andre             SP
# ...                         ...                      ...            ...
# 99436                     12209      sao jose dos campos             SP
# 99437                     11722             praia grande             SP
# 99438                     45920              nova vicosa             BA
# 99439                     28685                  japuiba             RJ
# 99440                     83750                     lapa             PR
#
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                           3149.0       -23.575816       -46.587303
# 1                          47813.0       -12.126533       -45.008244
# 2                          75265.0       -16.744472       -48.514624
# 3                          59296.0        -5.773971       -35.273838
# 4                           9195.0       -23.675471       -46.514788
# ...                            ...              ...              ...
# 99436                      12209.0       -23.177048       -45.884506
# 99437                      11722.0       -24.001467       -46.449577
# 99438                      45920.0       -17.897354       -39.372100
# 99439                      28685.0       -22.562040       -42.690186
# 99440                      83750.0       -25.766121       -49.720209
#
#               geolocation_city geolocation_state
# 0                    são paulo                SP
# 1                    barreiras                BA
# 2                   vianopolis                GO
# 3      são gonçalo do amarante                RN
# 4                  santo andre                SP
# ...                        ...               ...
# 99436      sao jose dos campos                SP
# 99437             praia grande                SP
# 99438              nova vicosa                BA
# 99439                  japuiba                RJ
# 99440                     lapa                PR
#
# [99441 rows x 17 columns]

# %%
# différences entre les villes
bd_diff_cities = df_olist_orders_customers_geo[df_olist_orders_customers_geo['customer_city'] != df_olist_orders_customers_geo['geolocation_city']][['customer_city', 'geolocation_city']]

# %%
bd_diff_cities
# Out:
#                  customer_city         geolocation_city
# 0                    sao paulo                são paulo
# 3      sao goncalo do amarante  são gonçalo do amarante
# 11                   sao paulo                são paulo
# 20                   sao paulo                são paulo
# 22                   sao paulo                são paulo
# ...                        ...                      ...
# 99407                sao paulo                são paulo
# 99414                sao paulo                são paulo
# 99417                 brasilia                 cruzeiro
# 99426                 brasilia                 brasília
# 99429                sao paulo                são paulo
#
# [10390 rows x 2 columns]

# %% [markdown]
# La différence entre les noms des villes apparait surtout suite à la forme normalisée dans *'customer_city'*

# %% [markdown]
# #### Nombre de geolocalisations manquantes

# %%
pd.isnull(df_olist_orders_customers_geo['geolocation_city']).sum()
# Out:
# 278

# %%
# création de la df contenant que des lignes avec l'information manquante sur la géolocalisation
df_orders_cust_geona = df_olist_orders_customers_geo[df_olist_orders_customers_geo['geolocation_city'].isna()]

# %%
df_orders_cust_geona
# Out:
#                                order_id                       customer_id  \
# 445    690199d6a2c51ff57c6b392d7680cbfd  19bacb562bd43bd4eaf05b6c0a59dad0
# 610    9f2da077d2d1eb6e8abcacef8776e941  2386792ff4818fe030a3b1364994f51e
# 681    1b00c4d80c81cdbc36487c96c6e92f07  6f392cfb40b84e0857b16c23c773aa31
# 926    7ebe19943d85e81a7b0eb108681276b7  fa3a8736d5ae8f7df9b0a4154d0b14dc
# 1091   d0bec96aad189992b278688279ba1511  f4302056f0c58570522590f8181de2c7
# ...                                 ...                               ...
# 97935  75f6ded14ff770cff5dab61532421db4  bbf5e98dabf1bdac752afc68f8032bda
# 98886  da47f3e1d422ef0acfa45d3a81f0085f  d14b76c93d237241c52e0e6767feb42a
# 99062  1a0e54c67a7d784f932f5cc4f953fbaf  baca33004aa726524d5a891853100559
# 99162  e1d102f12364768054a07dfa10fc43cc  f58c14ad1417ae5e8f9c6d0f9f6aec24
# 99217  2fe782855de414d2c2c51fcdb1437e3c  626a0f18050903535ecf8e312a5c028f
#
#       order_status order_purchase_timestamp    order_approved_at  \
# 445      delivered      2018-03-16 11:31:18  2018-03-16 11:49:14
# 610      delivered      2017-10-28 21:26:26  2017-10-28 21:46:29
# 681      delivered      2017-05-14 09:36:36  2017-05-16 03:22:50
# 926      delivered      2018-07-22 10:28:14  2018-07-23 11:31:43
# 1091     delivered      2018-05-08 21:04:16  2018-05-08 21:15:28
# ...            ...                      ...                  ...
# 97935    delivered      2018-04-03 08:37:21  2018-04-03 08:50:14
# 98886    delivered      2017-12-04 21:53:42  2017-12-05 10:30:46
# 99062    delivered      2017-06-16 21:56:39  2017-06-16 22:06:26
# 99162    delivered      2017-03-05 22:11:02  2017-03-05 22:25:16
# 99217    delivered      2018-08-01 07:13:41  2018-08-01 07:44:03
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 445            2018-03-19 19:56:23           2018-05-14 12:28:56
# 610            2017-11-06 11:08:52           2017-11-13 22:33:12
# 681            2017-05-16 12:05:28           2017-05-23 07:52:33
# 926            2018-07-23 10:09:00           2018-07-26 16:42:42
# 1091           2018-05-10 18:29:00           2018-05-21 13:06:35
# ...                            ...                           ...
# 97935          2018-04-04 19:28:19           2018-05-07 22:54:47
# 98886          2017-12-06 16:58:51           2017-12-19 16:23:35
# 99062          2017-06-20 15:30:45           2017-07-03 08:49:44
# 99162          2017-03-06 09:38:29           2017-03-23 15:06:37
# 99217          2018-08-03 04:29:00           2018-08-10 21:46:42
#
#       order_estimated_delivery_date                customer_unique_id  \
# 445             2018-04-11 00:00:00  c5f01991eadc43c924dfd891e9026217
# 610             2017-11-22 00:00:00  ab7bed4092cc3dadbaefba86cb45f37f
# 681             2017-06-02 00:00:00  5399c9213ca365a480537a1b21423d2c
# 926             2018-08-15 00:00:00  2de521d3fd097acfbd5bed9c7b9ed0d0
# 1091            2018-06-05 00:00:00  67b05b597a66b5c449025000b9430abb
# ...                             ...                               ...
# 97935           2018-04-20 00:00:00  13aba123512eef450a11646c572fccca
# 98886           2018-01-02 00:00:00  4a88a750280bdba0dd1f167ae2b68bfd
# 99062           2017-07-13 00:00:00  aa67457bb07fde4e952d67b038135bee
# 99162           2017-03-27 00:00:00  04a5a9b154c83e4b19258dcd0e4476ed
# 99217           2018-08-23 00:00:00  615eb18afcde37c5ed09c9d4109c41fa
#
#        customer_zip_code_prefix  customer_city customer_state  \
# 445                       87323  alto sao joao             PR
# 610                       73081       brasilia             DF
# 681                       28160  santo eduardo             RJ
# 926                       71551       brasilia             DF
# 1091                      64605          picos             PI
# ...                         ...            ...            ...
# 97935                     29949     sao mateus             ES
# 98886                     71919       brasilia             DF
# 99062                     73369       brasilia             DF
# 99162                     85118    palmeirinha             PR
# 99217                     56327      petrolina             PE
#
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 445                            NaN              NaN              NaN
# 610                            NaN              NaN              NaN
# 681                            NaN              NaN              NaN
# 926                            NaN              NaN              NaN
# 1091                           NaN              NaN              NaN
# ...                            ...              ...              ...
# 97935                          NaN              NaN              NaN
# 98886                          NaN              NaN              NaN
# 99062                          NaN              NaN              NaN
# 99162                          NaN              NaN              NaN
# 99217                          NaN              NaN              NaN
#
#       geolocation_city geolocation_state
# 445                NaN               NaN
# 610                NaN               NaN
# 681                NaN               NaN
# 926                NaN               NaN
# 1091               NaN               NaN
# ...                ...               ...
# 97935              NaN               NaN
# 98886              NaN               NaN
# 99062              NaN               NaN
# 99162              NaN               NaN
# 99217              NaN               NaN
#
# [278 rows x 17 columns]

# %%
# aggrégation des données de géolocalisation en fonction du nom de la ville
df_geofornan_agg = df_geo_without_duplicates.groupby('geolocation_city').agg({
    'geolocation_lat':'median',
    'geolocation_lng':'median', 
    'geolocation_state': 'last'
}).reset_index()

# %%
df_geofornan_agg
# Out:
#         geolocation_city  geolocation_lat  geolocation_lng geolocation_state
# 0               * cidade       -25.571748       -49.334374                PR
# 1     ...arraial do cabo       -22.969370       -42.029834                RJ
# 2         4o. centenario       -24.271860       -53.069433                PR
# 3          4º centenario       -24.279801       -53.074723                PR
# 4        abadia de goias       -16.766377       -49.435020                GO
# ...                  ...              ...              ...               ...
# 8006               áurea       -27.695009       -52.055076                RS
# 8007              ângulo       -23.194603       -51.916767                PR
# 8008       érico cardoso       -13.393047       -42.134282                BA
# 8009              óbidos        -1.906778       -55.515603                PA
# 8010                óleo       -22.939570       -49.339142                SP
#
# [8011 rows x 4 columns]

# %% [markdown]
# ## Imputation de données manquantes de géolocalisation  <a class="anchor" id="geo_fillin"></a>

# %%
df_orders_cust_geona_pre_merge = df_orders_cust_geona.copy()

# %%
df_orders_cust_geona_pre_merge['old_index'] = df_orders_cust_geona_pre_merge.index

# %%
# remplissage des valeurs de géolocalisation manquantes en fonction de coordonnées associées aux noms des villes
df_orders_cust_geofilledna = df_orders_cust_geona_pre_merge.merge(df_geofornan_agg, how='left', left_on='customer_city', right_on='geolocation_city')

# %%
df_orders_cust_geofilledna
# Out:
#                              order_id                       customer_id  \
# 0    690199d6a2c51ff57c6b392d7680cbfd  19bacb562bd43bd4eaf05b6c0a59dad0
# 1    9f2da077d2d1eb6e8abcacef8776e941  2386792ff4818fe030a3b1364994f51e
# 2    1b00c4d80c81cdbc36487c96c6e92f07  6f392cfb40b84e0857b16c23c773aa31
# 3    7ebe19943d85e81a7b0eb108681276b7  fa3a8736d5ae8f7df9b0a4154d0b14dc
# 4    d0bec96aad189992b278688279ba1511  f4302056f0c58570522590f8181de2c7
# ..                                ...                               ...
# 273  75f6ded14ff770cff5dab61532421db4  bbf5e98dabf1bdac752afc68f8032bda
# 274  da47f3e1d422ef0acfa45d3a81f0085f  d14b76c93d237241c52e0e6767feb42a
# 275  1a0e54c67a7d784f932f5cc4f953fbaf  baca33004aa726524d5a891853100559
# 276  e1d102f12364768054a07dfa10fc43cc  f58c14ad1417ae5e8f9c6d0f9f6aec24
# 277  2fe782855de414d2c2c51fcdb1437e3c  626a0f18050903535ecf8e312a5c028f
#
#     order_status order_purchase_timestamp    order_approved_at  \
# 0      delivered      2018-03-16 11:31:18  2018-03-16 11:49:14
# 1      delivered      2017-10-28 21:26:26  2017-10-28 21:46:29
# 2      delivered      2017-05-14 09:36:36  2017-05-16 03:22:50
# 3      delivered      2018-07-22 10:28:14  2018-07-23 11:31:43
# 4      delivered      2018-05-08 21:04:16  2018-05-08 21:15:28
# ..           ...                      ...                  ...
# 273    delivered      2018-04-03 08:37:21  2018-04-03 08:50:14
# 274    delivered      2017-12-04 21:53:42  2017-12-05 10:30:46
# 275    delivered      2017-06-16 21:56:39  2017-06-16 22:06:26
# 276    delivered      2017-03-05 22:11:02  2017-03-05 22:25:16
# 277    delivered      2018-08-01 07:13:41  2018-08-01 07:44:03
#
#     order_delivered_carrier_date order_delivered_customer_date  \
# 0            2018-03-19 19:56:23           2018-05-14 12:28:56
# 1            2017-11-06 11:08:52           2017-11-13 22:33:12
# 2            2017-05-16 12:05:28           2017-05-23 07:52:33
# 3            2018-07-23 10:09:00           2018-07-26 16:42:42
# 4            2018-05-10 18:29:00           2018-05-21 13:06:35
# ..                           ...                           ...
# 273          2018-04-04 19:28:19           2018-05-07 22:54:47
# 274          2017-12-06 16:58:51           2017-12-19 16:23:35
# 275          2017-06-20 15:30:45           2017-07-03 08:49:44
# 276          2017-03-06 09:38:29           2017-03-23 15:06:37
# 277          2018-08-03 04:29:00           2018-08-10 21:46:42
#
#     order_estimated_delivery_date                customer_unique_id  \
# 0             2018-04-11 00:00:00  c5f01991eadc43c924dfd891e9026217
# 1             2017-11-22 00:00:00  ab7bed4092cc3dadbaefba86cb45f37f
# 2             2017-06-02 00:00:00  5399c9213ca365a480537a1b21423d2c
# 3             2018-08-15 00:00:00  2de521d3fd097acfbd5bed9c7b9ed0d0
# 4             2018-06-05 00:00:00  67b05b597a66b5c449025000b9430abb
# ..                            ...                               ...
# 273           2018-04-20 00:00:00  13aba123512eef450a11646c572fccca
# 274           2018-01-02 00:00:00  4a88a750280bdba0dd1f167ae2b68bfd
# 275           2017-07-13 00:00:00  aa67457bb07fde4e952d67b038135bee
# 276           2017-03-27 00:00:00  04a5a9b154c83e4b19258dcd0e4476ed
# 277           2018-08-23 00:00:00  615eb18afcde37c5ed09c9d4109c41fa
#
#      customer_zip_code_prefix  ... geolocation_zip_code_prefix  \
# 0                       87323  ...                         NaN
# 1                       73081  ...                         NaN
# 2                       28160  ...                         NaN
# 3                       71551  ...                         NaN
# 4                       64605  ...                         NaN
# ..                        ...  ...                         ...
# 273                     29949  ...                         NaN
# 274                     71919  ...                         NaN
# 275                     73369  ...                         NaN
# 276                     85118  ...                         NaN
# 277                     56327  ...                         NaN
#
#     geolocation_lat_x  geolocation_lng_x  geolocation_city_x  \
# 0                 NaN                NaN                 NaN
# 1                 NaN                NaN                 NaN
# 2                 NaN                NaN                 NaN
# 3                 NaN                NaN                 NaN
# 4                 NaN                NaN                 NaN
# ..                ...                ...                 ...
# 273               NaN                NaN                 NaN
# 274               NaN                NaN                 NaN
# 275               NaN                NaN                 NaN
# 276               NaN                NaN                 NaN
# 277               NaN                NaN                 NaN
#
#      geolocation_state_x old_index geolocation_city_y  geolocation_lat_y  \
# 0                    NaN       445                NaN                NaN
# 1                    NaN       610           brasilia         -15.820008
# 2                    NaN       681                NaN                NaN
# 3                    NaN       926           brasilia         -15.820008
# 4                    NaN      1091              picos          -7.083213
# ..                   ...       ...                ...                ...
# 273                  NaN     97935         sao mateus         -18.719300
# 274                  NaN     98886           brasilia         -15.820008
# 275                  NaN     99062           brasilia         -15.820008
# 276                  NaN     99162                NaN                NaN
# 277                  NaN     99217          petrolina          -9.385096
#
#     geolocation_lng_y  geolocation_state_y
# 0                 NaN                  NaN
# 1          -47.979953                   DF
# 2                 NaN                  NaN
# 3          -47.979953                   DF
# 4          -41.468344                   PI
# ..                ...                  ...
# 273        -39.855049                   ES
# 274        -47.979953                   DF
# 275        -47.979953                   DF
# 276               NaN                  NaN
# 277        -40.501313                   PE
#
# [278 rows x 22 columns]

# %%
df_orders_cust_geofilledna.drop(['geolocation_lat_x','geolocation_lng_x','geolocation_city_x','geolocation_state_x'], axis=1, inplace=True)

# %%
df_orders_cust_geofilledna
# Out:
#                              order_id                       customer_id  \
# 0    690199d6a2c51ff57c6b392d7680cbfd  19bacb562bd43bd4eaf05b6c0a59dad0
# 1    9f2da077d2d1eb6e8abcacef8776e941  2386792ff4818fe030a3b1364994f51e
# 2    1b00c4d80c81cdbc36487c96c6e92f07  6f392cfb40b84e0857b16c23c773aa31
# 3    7ebe19943d85e81a7b0eb108681276b7  fa3a8736d5ae8f7df9b0a4154d0b14dc
# 4    d0bec96aad189992b278688279ba1511  f4302056f0c58570522590f8181de2c7
# ..                                ...                               ...
# 273  75f6ded14ff770cff5dab61532421db4  bbf5e98dabf1bdac752afc68f8032bda
# 274  da47f3e1d422ef0acfa45d3a81f0085f  d14b76c93d237241c52e0e6767feb42a
# 275  1a0e54c67a7d784f932f5cc4f953fbaf  baca33004aa726524d5a891853100559
# 276  e1d102f12364768054a07dfa10fc43cc  f58c14ad1417ae5e8f9c6d0f9f6aec24
# 277  2fe782855de414d2c2c51fcdb1437e3c  626a0f18050903535ecf8e312a5c028f
#
#     order_status order_purchase_timestamp    order_approved_at  \
# 0      delivered      2018-03-16 11:31:18  2018-03-16 11:49:14
# 1      delivered      2017-10-28 21:26:26  2017-10-28 21:46:29
# 2      delivered      2017-05-14 09:36:36  2017-05-16 03:22:50
# 3      delivered      2018-07-22 10:28:14  2018-07-23 11:31:43
# 4      delivered      2018-05-08 21:04:16  2018-05-08 21:15:28
# ..           ...                      ...                  ...
# 273    delivered      2018-04-03 08:37:21  2018-04-03 08:50:14
# 274    delivered      2017-12-04 21:53:42  2017-12-05 10:30:46
# 275    delivered      2017-06-16 21:56:39  2017-06-16 22:06:26
# 276    delivered      2017-03-05 22:11:02  2017-03-05 22:25:16
# 277    delivered      2018-08-01 07:13:41  2018-08-01 07:44:03
#
#     order_delivered_carrier_date order_delivered_customer_date  \
# 0            2018-03-19 19:56:23           2018-05-14 12:28:56
# 1            2017-11-06 11:08:52           2017-11-13 22:33:12
# 2            2017-05-16 12:05:28           2017-05-23 07:52:33
# 3            2018-07-23 10:09:00           2018-07-26 16:42:42
# 4            2018-05-10 18:29:00           2018-05-21 13:06:35
# ..                           ...                           ...
# 273          2018-04-04 19:28:19           2018-05-07 22:54:47
# 274          2017-12-06 16:58:51           2017-12-19 16:23:35
# 275          2017-06-20 15:30:45           2017-07-03 08:49:44
# 276          2017-03-06 09:38:29           2017-03-23 15:06:37
# 277          2018-08-03 04:29:00           2018-08-10 21:46:42
#
#     order_estimated_delivery_date                customer_unique_id  \
# 0             2018-04-11 00:00:00  c5f01991eadc43c924dfd891e9026217
# 1             2017-11-22 00:00:00  ab7bed4092cc3dadbaefba86cb45f37f
# 2             2017-06-02 00:00:00  5399c9213ca365a480537a1b21423d2c
# 3             2018-08-15 00:00:00  2de521d3fd097acfbd5bed9c7b9ed0d0
# 4             2018-06-05 00:00:00  67b05b597a66b5c449025000b9430abb
# ..                            ...                               ...
# 273           2018-04-20 00:00:00  13aba123512eef450a11646c572fccca
# 274           2018-01-02 00:00:00  4a88a750280bdba0dd1f167ae2b68bfd
# 275           2017-07-13 00:00:00  aa67457bb07fde4e952d67b038135bee
# 276           2017-03-27 00:00:00  04a5a9b154c83e4b19258dcd0e4476ed
# 277           2018-08-23 00:00:00  615eb18afcde37c5ed09c9d4109c41fa
#
#      customer_zip_code_prefix  customer_city customer_state  \
# 0                       87323  alto sao joao             PR
# 1                       73081       brasilia             DF
# 2                       28160  santo eduardo             RJ
# 3                       71551       brasilia             DF
# 4                       64605          picos             PI
# ..                        ...            ...            ...
# 273                     29949     sao mateus             ES
# 274                     71919       brasilia             DF
# 275                     73369       brasilia             DF
# 276                     85118    palmeirinha             PR
# 277                     56327      petrolina             PE
#
#      geolocation_zip_code_prefix  old_index geolocation_city_y  \
# 0                            NaN        445                NaN
# 1                            NaN        610           brasilia
# 2                            NaN        681                NaN
# 3                            NaN        926           brasilia
# 4                            NaN       1091              picos
# ..                           ...        ...                ...
# 273                          NaN      97935         sao mateus
# 274                          NaN      98886           brasilia
# 275                          NaN      99062           brasilia
# 276                          NaN      99162                NaN
# 277                          NaN      99217          petrolina
#
#      geolocation_lat_y  geolocation_lng_y geolocation_state_y
# 0                  NaN                NaN                 NaN
# 1           -15.820008         -47.979953                  DF
# 2                  NaN                NaN                 NaN
# 3           -15.820008         -47.979953                  DF
# 4            -7.083213         -41.468344                  PI
# ..                 ...                ...                 ...
# 273         -18.719300         -39.855049                  ES
# 274         -15.820008         -47.979953                  DF
# 275         -15.820008         -47.979953                  DF
# 276                NaN                NaN                 NaN
# 277          -9.385096         -40.501313                  PE
#
# [278 rows x 18 columns]

# %%
df_orders_cust_geofilledna.rename(columns={"geolocation_city_y": "geolocation_city", "geolocation_lat_y": "geolocation_lat",
                                          "geolocation_lng_y": "geolocation_lng", "geolocation_state_y": "geolocation_state"},
                                  inplace = True)

# %%
df_orders_cust_geofilledna
# Out:
#                              order_id                       customer_id  \
# 0    690199d6a2c51ff57c6b392d7680cbfd  19bacb562bd43bd4eaf05b6c0a59dad0
# 1    9f2da077d2d1eb6e8abcacef8776e941  2386792ff4818fe030a3b1364994f51e
# 2    1b00c4d80c81cdbc36487c96c6e92f07  6f392cfb40b84e0857b16c23c773aa31
# 3    7ebe19943d85e81a7b0eb108681276b7  fa3a8736d5ae8f7df9b0a4154d0b14dc
# 4    d0bec96aad189992b278688279ba1511  f4302056f0c58570522590f8181de2c7
# ..                                ...                               ...
# 273  75f6ded14ff770cff5dab61532421db4  bbf5e98dabf1bdac752afc68f8032bda
# 274  da47f3e1d422ef0acfa45d3a81f0085f  d14b76c93d237241c52e0e6767feb42a
# 275  1a0e54c67a7d784f932f5cc4f953fbaf  baca33004aa726524d5a891853100559
# 276  e1d102f12364768054a07dfa10fc43cc  f58c14ad1417ae5e8f9c6d0f9f6aec24
# 277  2fe782855de414d2c2c51fcdb1437e3c  626a0f18050903535ecf8e312a5c028f
#
#     order_status order_purchase_timestamp    order_approved_at  \
# 0      delivered      2018-03-16 11:31:18  2018-03-16 11:49:14
# 1      delivered      2017-10-28 21:26:26  2017-10-28 21:46:29
# 2      delivered      2017-05-14 09:36:36  2017-05-16 03:22:50
# 3      delivered      2018-07-22 10:28:14  2018-07-23 11:31:43
# 4      delivered      2018-05-08 21:04:16  2018-05-08 21:15:28
# ..           ...                      ...                  ...
# 273    delivered      2018-04-03 08:37:21  2018-04-03 08:50:14
# 274    delivered      2017-12-04 21:53:42  2017-12-05 10:30:46
# 275    delivered      2017-06-16 21:56:39  2017-06-16 22:06:26
# 276    delivered      2017-03-05 22:11:02  2017-03-05 22:25:16
# 277    delivered      2018-08-01 07:13:41  2018-08-01 07:44:03
#
#     order_delivered_carrier_date order_delivered_customer_date  \
# 0            2018-03-19 19:56:23           2018-05-14 12:28:56
# 1            2017-11-06 11:08:52           2017-11-13 22:33:12
# 2            2017-05-16 12:05:28           2017-05-23 07:52:33
# 3            2018-07-23 10:09:00           2018-07-26 16:42:42
# 4            2018-05-10 18:29:00           2018-05-21 13:06:35
# ..                           ...                           ...
# 273          2018-04-04 19:28:19           2018-05-07 22:54:47
# 274          2017-12-06 16:58:51           2017-12-19 16:23:35
# 275          2017-06-20 15:30:45           2017-07-03 08:49:44
# 276          2017-03-06 09:38:29           2017-03-23 15:06:37
# 277          2018-08-03 04:29:00           2018-08-10 21:46:42
#
#     order_estimated_delivery_date                customer_unique_id  \
# 0             2018-04-11 00:00:00  c5f01991eadc43c924dfd891e9026217
# 1             2017-11-22 00:00:00  ab7bed4092cc3dadbaefba86cb45f37f
# 2             2017-06-02 00:00:00  5399c9213ca365a480537a1b21423d2c
# 3             2018-08-15 00:00:00  2de521d3fd097acfbd5bed9c7b9ed0d0
# 4             2018-06-05 00:00:00  67b05b597a66b5c449025000b9430abb
# ..                            ...                               ...
# 273           2018-04-20 00:00:00  13aba123512eef450a11646c572fccca
# 274           2018-01-02 00:00:00  4a88a750280bdba0dd1f167ae2b68bfd
# 275           2017-07-13 00:00:00  aa67457bb07fde4e952d67b038135bee
# 276           2017-03-27 00:00:00  04a5a9b154c83e4b19258dcd0e4476ed
# 277           2018-08-23 00:00:00  615eb18afcde37c5ed09c9d4109c41fa
#
#      customer_zip_code_prefix  customer_city customer_state  \
# 0                       87323  alto sao joao             PR
# 1                       73081       brasilia             DF
# 2                       28160  santo eduardo             RJ
# 3                       71551       brasilia             DF
# 4                       64605          picos             PI
# ..                        ...            ...            ...
# 273                     29949     sao mateus             ES
# 274                     71919       brasilia             DF
# 275                     73369       brasilia             DF
# 276                     85118    palmeirinha             PR
# 277                     56327      petrolina             PE
#
#      geolocation_zip_code_prefix  old_index geolocation_city  geolocation_lat  \
# 0                            NaN        445              NaN              NaN
# 1                            NaN        610         brasilia       -15.820008
# 2                            NaN        681              NaN              NaN
# 3                            NaN        926         brasilia       -15.820008
# 4                            NaN       1091            picos        -7.083213
# ..                           ...        ...              ...              ...
# 273                          NaN      97935       sao mateus       -18.719300
# 274                          NaN      98886         brasilia       -15.820008
# 275                          NaN      99062         brasilia       -15.820008
# 276                          NaN      99162              NaN              NaN
# 277                          NaN      99217        petrolina        -9.385096
#
#      geolocation_lng geolocation_state
# 0                NaN               NaN
# 1         -47.979953                DF
# 2                NaN               NaN
# 3         -47.979953                DF
# 4         -41.468344                PI
# ..               ...               ...
# 273       -39.855049                ES
# 274       -47.979953                DF
# 275       -47.979953                DF
# 276              NaN               NaN
# 277       -40.501313                PE
#
# [278 rows x 18 columns]

# %%
df_orders_cust_geofilledna.set_index(df_orders_cust_geofilledna['old_index'], inplace=True)

# %%
df_orders_cust_geofilledna
# Out:
#                                    order_id                       customer_id  \
# old_index
# 445        690199d6a2c51ff57c6b392d7680cbfd  19bacb562bd43bd4eaf05b6c0a59dad0
# 610        9f2da077d2d1eb6e8abcacef8776e941  2386792ff4818fe030a3b1364994f51e
# 681        1b00c4d80c81cdbc36487c96c6e92f07  6f392cfb40b84e0857b16c23c773aa31
# 926        7ebe19943d85e81a7b0eb108681276b7  fa3a8736d5ae8f7df9b0a4154d0b14dc
# 1091       d0bec96aad189992b278688279ba1511  f4302056f0c58570522590f8181de2c7
# ...                                     ...                               ...
# 97935      75f6ded14ff770cff5dab61532421db4  bbf5e98dabf1bdac752afc68f8032bda
# 98886      da47f3e1d422ef0acfa45d3a81f0085f  d14b76c93d237241c52e0e6767feb42a
# 99062      1a0e54c67a7d784f932f5cc4f953fbaf  baca33004aa726524d5a891853100559
# 99162      e1d102f12364768054a07dfa10fc43cc  f58c14ad1417ae5e8f9c6d0f9f6aec24
# 99217      2fe782855de414d2c2c51fcdb1437e3c  626a0f18050903535ecf8e312a5c028f
#
#           order_status order_purchase_timestamp    order_approved_at  \
# old_index
# 445          delivered      2018-03-16 11:31:18  2018-03-16 11:49:14
# 610          delivered      2017-10-28 21:26:26  2017-10-28 21:46:29
# 681          delivered      2017-05-14 09:36:36  2017-05-16 03:22:50
# 926          delivered      2018-07-22 10:28:14  2018-07-23 11:31:43
# 1091         delivered      2018-05-08 21:04:16  2018-05-08 21:15:28
# ...                ...                      ...                  ...
# 97935        delivered      2018-04-03 08:37:21  2018-04-03 08:50:14
# 98886        delivered      2017-12-04 21:53:42  2017-12-05 10:30:46
# 99062        delivered      2017-06-16 21:56:39  2017-06-16 22:06:26
# 99162        delivered      2017-03-05 22:11:02  2017-03-05 22:25:16
# 99217        delivered      2018-08-01 07:13:41  2018-08-01 07:44:03
#
#           order_delivered_carrier_date order_delivered_customer_date  \
# old_index
# 445                2018-03-19 19:56:23           2018-05-14 12:28:56
# 610                2017-11-06 11:08:52           2017-11-13 22:33:12
# 681                2017-05-16 12:05:28           2017-05-23 07:52:33
# 926                2018-07-23 10:09:00           2018-07-26 16:42:42
# 1091               2018-05-10 18:29:00           2018-05-21 13:06:35
# ...                                ...                           ...
# 97935              2018-04-04 19:28:19           2018-05-07 22:54:47
# 98886              2017-12-06 16:58:51           2017-12-19 16:23:35
# 99062              2017-06-20 15:30:45           2017-07-03 08:49:44
# 99162              2017-03-06 09:38:29           2017-03-23 15:06:37
# 99217              2018-08-03 04:29:00           2018-08-10 21:46:42
#
#           order_estimated_delivery_date                customer_unique_id  \
# old_index
# 445                 2018-04-11 00:00:00  c5f01991eadc43c924dfd891e9026217
# 610                 2017-11-22 00:00:00  ab7bed4092cc3dadbaefba86cb45f37f
# 681                 2017-06-02 00:00:00  5399c9213ca365a480537a1b21423d2c
# 926                 2018-08-15 00:00:00  2de521d3fd097acfbd5bed9c7b9ed0d0
# 1091                2018-06-05 00:00:00  67b05b597a66b5c449025000b9430abb
# ...                                 ...                               ...
# 97935               2018-04-20 00:00:00  13aba123512eef450a11646c572fccca
# 98886               2018-01-02 00:00:00  4a88a750280bdba0dd1f167ae2b68bfd
# 99062               2017-07-13 00:00:00  aa67457bb07fde4e952d67b038135bee
# 99162               2017-03-27 00:00:00  04a5a9b154c83e4b19258dcd0e4476ed
# 99217               2018-08-23 00:00:00  615eb18afcde37c5ed09c9d4109c41fa
#
#            customer_zip_code_prefix  customer_city customer_state  \
# old_index
# 445                           87323  alto sao joao             PR
# 610                           73081       brasilia             DF
# 681                           28160  santo eduardo             RJ
# 926                           71551       brasilia             DF
# 1091                          64605          picos             PI
# ...                             ...            ...            ...
# 97935                         29949     sao mateus             ES
# 98886                         71919       brasilia             DF
# 99062                         73369       brasilia             DF
# 99162                         85118    palmeirinha             PR
# 99217                         56327      petrolina             PE
#
#            geolocation_zip_code_prefix  old_index geolocation_city  \
# old_index
# 445                                NaN        445              NaN
# 610                                NaN        610         brasilia
# 681                                NaN        681              NaN
# 926                                NaN        926         brasilia
# 1091                               NaN       1091            picos
# ...                                ...        ...              ...
# 97935                              NaN      97935       sao mateus
# 98886                              NaN      98886         brasilia
# 99062                              NaN      99062         brasilia
# 99162                              NaN      99162              NaN
# 99217                              NaN      99217        petrolina
#
#            geolocation_lat  geolocation_lng geolocation_state
# old_index
# 445                    NaN              NaN               NaN
# 610             -15.820008       -47.979953                DF
# 681                    NaN              NaN               NaN
# 926             -15.820008       -47.979953                DF
# 1091             -7.083213       -41.468344                PI
# ...                    ...              ...               ...
# 97935           -18.719300       -39.855049                ES
# 98886           -15.820008       -47.979953                DF
# 99062           -15.820008       -47.979953                DF
# 99162                  NaN              NaN               NaN
# 99217            -9.385096       -40.501313                PE
#
# [278 rows x 18 columns]

# %%
df_orders_cust_geofilledna['geolocation_city'].isna().sum()
# Out:
# 49

# %% [markdown]
# Il reste 49 NaN. On crée une nouvelle df ('df_orders_cust_geoetranger') avec ses lignes

# %%
df_orders_cust_geoetranger = df_orders_cust_geofilledna[df_orders_cust_geofilledna['geolocation_city'].isna()].copy()

# %%
list_cities = df_geo_without_duplicates['geolocation_city'].unique()

# %%
list_cities
# Out:
# array(['sao paulo', 'são paulo', 'sao bernardo do campo', ..., 'ciríaco',
#        'estação', 'vila lângaro'], dtype=object)

# %%
with open('listfile.txt', 'w', encoding='utf8') as filehandle:
    for listitem in list_cities:
        filehandle.write('%s\n' % listitem)

# %% [raw]
# # installation de librairie permettant de récupérer les coordonnées géographique via Google Maps ou autres services
# pip install geopy

# %%
# source de code: https://www.askpython.com/python/python-geopy-to-find-geocode-of-an-address
#Creating an instance of Nominatim Class
geolocator = Nominatim(user_agent="my_request")

# %%
#applying the rate limiter wrapper
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)

# %%
df_orders_cust_geoetranger
# Out:
#                                    order_id                       customer_id  \
# old_index
# 445        690199d6a2c51ff57c6b392d7680cbfd  19bacb562bd43bd4eaf05b6c0a59dad0
# 681        1b00c4d80c81cdbc36487c96c6e92f07  6f392cfb40b84e0857b16c23c773aa31
# 5497       ae78d443f07cc7da4cb961f34f1bc6a8  aa4c5b95810a5d4b1bf2cc56e7d76cd6
# 6559       6c187a778a170f2bc6beac3979e3a81c  e37623a7c983c5174d5aea2aad30a080
# 7553       5050bad26c6099dce48e97368a53f149  f341549b5b28a46a5b4db2f4372e36a2
# 10699      7bac1567c0592387d6b83a189f7d25ef  4a5642b29f7d0885758928dc7ec35909
# 14006      7a36ddcacbdd80a7dd8771aa4c6e465e  e988b94fc82408ecac8299c744959c58
# 14664      2ee460773e708be4e0208745a3864b8c  3bd12f7c1ad3a3908905785e43de8603
# 17005      971e55ce6ef3eae4af8292bd71c8e27f  8a629de914739aa508711c4311abf537
# 17153      19b6861ce084842fb4ec0cafc59deebe  78a11bb1fa72f556996b9a5b9bcd0629
# 21025      15c73309f9a91be9baa4d58d1e02cbab  59365a596fafb5488c739ac1e657f6ab
# 24670      de5663895e88028a4c5a84d46b7475cc  c785e91c77b1e2fc9f642dbf170adbd4
# 25708      a389c8dd641e5e3bd97578e44f1ece83  7b0a3a430a7e8b6183eac952df55cb07
# 61841               2017-03-29 00:00:00  a33bb670bdfc972c485c44923aece1df
# 63762               2018-08-23 00:00:00  9762e6c31b598116ac89680124fe173e
# 64560               2017-11-10 00:00:00  fac8b5e914037fc2e2476783585f0769
# 66852               2018-03-06 00:00:00  7ee645e84a436c9dad3d5af253162fe7
# 67963               2017-04-24 00:00:00  c9d0b6cc7d9fccb750ba1cc6c4b76ecb
# 70065               2018-07-12 00:00:00  8b1ea5b8958ebfa320d33b80215dfbc6
# 70788               2018-06-21 00:00:00  e9a5ffad71fbb203da7c2661b647cc9a
# 71500               2018-04-18 00:00:00  924f226bd0426ed28ec908a135b18950
# 72041               2017-04-19 00:00:00  2f37a695478fbf531a61d086b444a634
# 72397               2017-11-29 00:00:00  d647bd6f2997e98e04f7d84da752b873
# 75034               2018-07-17 00:00:00  bfe6b5289dd1cec948d3714ae5453392
# 80750               2018-04-26 00:00:00  69b09832dc41358029209b44f47854ff
# 86802               2017-12-26 00:00:00  3858e59d2965f2cf2d49f28ea26ec172
# 87246               2017-12-14 00:00:00  3815e5fe3869fb75b982acc9da267b9f
# 88308               2018-03-23 00:00:00  b501aa16c4c71c55bd43d45d112bd135
# 92991               2017-10-20 00:00:00  cf717ffae55d20f545be20358a44f698
# 95628               2017-12-19 00:00:00  6c9871f7c55b411fabb59d9130b51e6d
# 99162               2017-03-27 00:00:00  04a5a9b154c83e4b19258dcd0e4476ed
#
#            customer_zip_code_prefix                 customer_city  \
# old_index
# 445                           87323                 alto sao joao
# 681                           28160                 santo eduardo
# 5497                          59299                 poco de pedra
# 6559                          83843                   doce grande
# 7553                           6930                    cipo-guacu
# 10699                         75784             domiciano ribeiro
# 14006                         29718              angelo frechiani
# 14664                         65137                        maioba
# 17005                         28575                    jaguarembe
# 17153                         55863                        siriji
# 21025                         28120                      ibitioca
# 24670                         36596             estevao de araujo
# 25708                         85894                  sao clemente
# 27154                         35408                        glaura
# 27486                         75784             domiciano ribeiro
# 27944                         28530      sao sebastiao do paraiba
# 31408                         36857                     pinhotiba
# 36615                         85118                   palmeirinha
# 38553                         28388         bom jesus do querendo
# 38613                         17390        sao sebastiao da serra
# 43578                         36248          conceicao do formoso
# 47177                         65137                        maioba
# 48101                         35242                   cuite velho
# 52868                         28160                 santo eduardo
# 54274                         86996          sao miguel do cambui
# 57090                         36956      sao francisco do humaita
# 57410                         58734                      passagem
# 57509                         25840                      bemposta
# 58357                         38710                   major porto
# 59563                         62625                         missi
# 61555                         95572                     mampituba
# 61841                         42843                          jaua
# 63762                         39103                        guinda
# 64560                         65137                        maioba
# 66852                          8980      nossa senhora do remedio
# 67963                         38627             palmital de minas
# 70065                         85958           perola independente
# 70788                         19740                          bora
# 71500                          8980      nossa senhora do remedio
# 72041                         44135                      humildes
# 72397                         28655                      monnerat
# 75034                         49870                         itabi
# 80750                         58286            pitanga de estrada
# 86802                         28655                      monnerat
# 87246                         48504                       aribice
# 88308                         95853  polo petroquimico de triunfo
# 92991                         35104                     sao vitor
# 95628                         65830                      sambaiba
# 99162                         85118                   palmeirinha
#
#           customer_state  geolocation_zip_code_prefix  old_index  \
# old_index
# 445                   PR                          NaN        445
# 681                   RJ                          NaN        681
# 5497                  RN                          NaN       5497
# 6559                  PR                          NaN       6559
# 7553                  SP                          NaN       7553
# 10699                 GO                          NaN      10699
# 14006                 ES                          NaN      14006
# 14664                 MA                          NaN      14664
# 17005                 RJ                          NaN      17005
# 17153                 PE                          NaN      17153
# 21025                 RJ                          NaN      21025
# 24670                 MG                          NaN      24670
# 25708                 PR                          NaN      25708
# 27154                 MG                          NaN      27154
# 27486                 GO                          NaN      27486
# 27944                 RJ                          NaN      27944
# 31408                 MG                          NaN      31408
# 36615                 PR                          NaN      36615
# 38553                 RJ                          NaN      38553
# 38613                 SP                          NaN      38613
# 43578                 MG                          NaN      43578
# 47177                 MA                          NaN      47177
# 48101                 MG                          NaN      48101
# 52868                 RJ                          NaN      52868
# 54274                 PR                          NaN      54274
# 57090                 MG                          NaN      57090
# 57410                 PB                          NaN      57410
# 57509                 RJ                          NaN      57509
# 58357                 MG                          NaN      58357
# 59563                 CE                          NaN      59563
# 61555                 RS                          NaN      61555
# 61841                 BA                          NaN      61841
# 63762                 MG                          NaN      63762
# 64560                 MA                          NaN      64560
# 66852                 SP                          NaN      66852
# 67963                 MG                          NaN      67963
# 70065                 PR                          NaN      70065
# 70788                 SP                          NaN      70788
# 71500                 SP                          NaN      71500
# 72041                 BA                          NaN      72041
# 72397                 RJ                          NaN      72397
# 75034                 SE                          NaN      75034
# 80750                 PB                          NaN      80750
# 86802                 RJ                          NaN      86802
# 87246                 BA                          NaN      87246
# 88308                 RS                          NaN      88308
# 92991                 MG                          NaN      92991
# 95628                 MA                          NaN      95628
# 99162                 PR                          NaN      99162
#
#           geolocation_city  geolocation_lat  geolocation_lng geolocation_state
# old_index
# 445                    NaN              NaN              NaN               NaN
# 681                    NaN              NaN              NaN               NaN
# 5497                   NaN              NaN              NaN               NaN
# 6559                   NaN              NaN              NaN               NaN
# 7553                   NaN              NaN              NaN               NaN
# 10699                  NaN              NaN              NaN               NaN
# 14006                  NaN              NaN              NaN               NaN
# 14664                  NaN              NaN              NaN               NaN
# 17005                  NaN              NaN              NaN               NaN
# 17153                  NaN              NaN              NaN               NaN
# 21025                  NaN              NaN              NaN               NaN
# 24670                  NaN              NaN              NaN               NaN
# 25708                  NaN              NaN              NaN               NaN
# 27154                  NaN              NaN              NaN               NaN
# 27486                  NaN              NaN              NaN               NaN
# 27944                  NaN              NaN              NaN               NaN
# 31408                  NaN              NaN              NaN               NaN
# 36615                  NaN              NaN              NaN               NaN
# 38553                  NaN              NaN              NaN               NaN
# 38613                  NaN              NaN              NaN               NaN
# 43578                  NaN              NaN              NaN               NaN
# 47177                  NaN              NaN              NaN               NaN
# 48101                  NaN              NaN              NaN               NaN
# 52868                  NaN              NaN              NaN               NaN
# 54274                  NaN              NaN              NaN               NaN
# 57090                  NaN              NaN              NaN               NaN
# 57410                  NaN              NaN              NaN               NaN
# 57509                  NaN              NaN              NaN               NaN
# 58357                  NaN              NaN              NaN               NaN
# 59563                  NaN              NaN              NaN               NaN
# 61555                  NaN              NaN              NaN               NaN
# 61841                  NaN              NaN              NaN               NaN
# 63762                  NaN              NaN              NaN               NaN
# 64560                  NaN              NaN              NaN               NaN
# 66852                  NaN              NaN              NaN               NaN
# 67963                  NaN              NaN              NaN               NaN
# 70065                  NaN              NaN              NaN               NaN
# 70788                  NaN              NaN              NaN               NaN
# 71500                  NaN              NaN              NaN               NaN
# 72041                  NaN              NaN              NaN               NaN
# 72397                  NaN              NaN              NaN               NaN
# 75034                  NaN              NaN              NaN               NaN
# 80750                  NaN              NaN              NaN               NaN
# 86802                  NaN              NaN              NaN               NaN
# 87246                  NaN              NaN              NaN               NaN
# 88308                  NaN              NaN              NaN               NaN
# 92991                  NaN              NaN              NaN               NaN
# 95628                  NaN              NaN              NaN               NaN
# 99162                  NaN              NaN              NaN               NaN

# %%
# test de cancatenation de l'information pour plus de précision dans le résultat
#df_orders_cust_geoetranger['full_adress'] = df_orders_cust_geoetranger['customer_zip_code_prefix'].map(str) + ', ' + df_orders_cust_geoetranger['customer_city']

# %%
#Applying the method to pandas DataFrame
df_orders_cust_geoetranger['location'] = df_orders_cust_geoetranger['customer_city'].apply(geocode)
df_orders_cust_geoetranger['geolocation_lat'] = df_orders_cust_geoetranger['location'].apply(lambda x: x.latitude if x else None)
df_orders_cust_geoetranger['geolocation_lng'] = df_orders_cust_geoetranger['location'].apply(lambda x: x.longitude if x else None)

# %%
df_orders_cust_geoetranger
# Out:
#                                    order_id                       customer_id  \
# old_index
# 445        690199d6a2c51ff57c6b392d7680cbfd  19bacb562bd43bd4eaf05b6c0a59dad0
# 681        1b00c4d80c81cdbc36487c96c6e92f07  6f392cfb40b84e0857b16c23c773aa31
# 5497       ae78d443f07cc7da4cb961f34f1bc6a8  aa4c5b95810a5d4b1bf2cc56e7d76cd6
# 6559       6c187a778a170f2bc6beac3979e3a81c  e37623a7c983c5174d5aea2aad30a080
# 7553       5050bad26c6099dce48e97368a53f149  f341549b5b28a46a5b4db2f4372e36a2
# 10699      7bac1567c0592387d6b83a189f7d25ef  4a5642b29f7d0885758928dc7ec35909
# 14006      7a36ddcacbdd80a7dd8771aa4c6e465e  e988b94fc82408ecac8299c744959c58
# 14664      2ee460773e708be4e0208745a3864b8c  3bd12f7c1ad3a3908905785e43de8603
# 17005      971e55ce6ef3eae4af8292bd71c8e27f  8a629de914739aa508711c4311abf537
# 17153      19b6861ce084842fb4ec0cafc59deebe  78a11bb1fa72f556996b9a5b9bcd0629
# 21025      15c73309f9a91be9baa4d58d1e02cbab  59365a596fafb5488c739ac1e657f6ab
# 24670      de5663895e88028a4c5a84d46b7475cc  c785e91c77b1e2fc9f642dbf170adbd4
# 25708      a389c8dd641e5e3bd97578e44f1ece83  7b0a3a430a7e8b6183eac952df55cb07
# 27154      30ee51f86a9d676801e824efd4aad215  c55a17a7c31353c35d48550b3aebc06f
# 27486      eca75747f628939976e814e7972bfea8  ce102f790bb667f9851019a3cb0ed958
# 27944      84a80b02b3af075990fc7d9d2369f066  f792e419335df11d82c32efcfb09c51b
# 31408      675ea662391ef609e39645b25940d453  7d643c6504deebe6d2ab830865d71584
# 70065               2018-07-12 00:00:00  8b1ea5b8958ebfa320d33b80215dfbc6
# 70788               2018-06-21 00:00:00  e9a5ffad71fbb203da7c2661b647cc9a
# 71500               2018-04-18 00:00:00  924f226bd0426ed28ec908a135b18950
# 72041               2017-04-19 00:00:00  2f37a695478fbf531a61d086b444a634
# 72397               2017-11-29 00:00:00  d647bd6f2997e98e04f7d84da752b873
# 75034               2018-07-17 00:00:00  bfe6b5289dd1cec948d3714ae5453392
# 80750               2018-04-26 00:00:00  69b09832dc41358029209b44f47854ff
# 86802               2017-12-26 00:00:00  3858e59d2965f2cf2d49f28ea26ec172
# 87246               2017-12-14 00:00:00  3815e5fe3869fb75b982acc9da267b9f
# 88308               2018-03-23 00:00:00  b501aa16c4c71c55bd43d45d112bd135
# 92991               2017-10-20 00:00:00  cf717ffae55d20f545be20358a44f698
# 95628               2017-12-19 00:00:00  6c9871f7c55b411fabb59d9130b51e6d
# 99162               2017-03-27 00:00:00  04a5a9b154c83e4b19258dcd0e4476ed
#
#            customer_zip_code_prefix                 customer_city  \
# old_index
# 445                           87323                 alto sao joao
# 681                           28160                 santo eduardo
# 5497                          59299                 poco de pedra
# 6559                          83843                   doce grande
# 7553                           6930                    cipo-guacu
# 10699                         75784             domiciano ribeiro
# 14006                         29718              angelo frechiani
# 14664                         65137                        maioba
# 17005                         28575                    jaguarembe
# 17153                         55863                        siriji
# 21025                         28120                      ibitioca
# 24670                         36596             estevao de araujo
# 25708                         85894                  sao clemente
# 27154                         35408                        glaura
# 27486                         75784             domiciano ribeiro
# 27944                         28530      sao sebastiao do paraiba
# 31408                         36857                     pinhotiba
# 36615                         85118                   palmeirinha
# 38553                         28388         bom jesus do querendo
# 38613                         17390        sao sebastiao da serra
# 43578                         36248          conceicao do formoso
# 47177                         65137                        maioba
# 48101                         35242                   cuite velho
# 52868                         28160                 santo eduardo
# 54274                         86996          sao miguel do cambui
# 57090                         36956      sao francisco do humaita
# 57410                         58734                      passagem
# 57509                         25840                      bemposta
# 58357                         38710                   major porto
# 59563                         62625                         missi
# 61555                         95572                     mampituba
# 61841                         42843                          jaua
# 63762                         39103                        guinda
# 64560                         65137                        maioba
# 66852                          8980      nossa senhora do remedio
# 67963                         38627             palmital de minas
# 70065                         85958           perola independente
# 70788                         19740                          bora
# 71500                          8980      nossa senhora do remedio
# 72041                         44135                      humildes
# 72397                         28655                      monnerat
# 75034                         49870                         itabi
# 80750                         58286            pitanga de estrada
# 86802                         28655                      monnerat
# 87246                         48504                       aribice
# 88308                         95853  polo petroquimico de triunfo
# 92991                         35104                     sao vitor
# 95628                         65830                      sambaiba
# 99162                         85118                   palmeirinha
#
#           customer_state  geolocation_zip_code_prefix  old_index  \
# old_index
# 445                   PR                          NaN        445
# 681                   RJ                          NaN        681
# 5497                  RN                          NaN       5497
# 6559                  PR                          NaN       6559
# 7553                  SP                          NaN       7553
# 10699                 GO                          NaN      10699
# 14006                 ES                          NaN      14006
# 14664                 MA                          NaN      14664
# 17005                 RJ                          NaN      17005
# 17153                 PE                          NaN      17153
# 21025                 RJ                          NaN      21025
# 66852                   NaN  (Nossa Senhora do Remédio, Salesópolis, Região...
# 67963                   NaN  (Palmital de Minas, Cabeceira Grande, Microrre...
# 70065                   NaN  (Pérola Independente, Maripá, Região Geográfic...
# 70788                   NaN  (Borá, Região Imediata de Assis, Região Geográ...
# 71500                   NaN  (Nossa Senhora do Remédio, Salesópolis, Região...
# 72041                   NaN  (Humildes, Feira de Santana, Região Geográfica...
# 72397                   NaN  (Monnerat, Duas Barras, Região Geográfica Imed...
# 75034                   NaN  (Itabi, Região Geográfica Imediata de Nossa Se...
# 80750                   NaN  (pitanga, Estrada Para Chã da Alegria, Paudalh...
# 86802                   NaN  (Monnerat, Duas Barras, Região Geográfica Imed...
# 87246                   NaN  (Aribice, Euclides da Cunha, Região Geográfica...
# 88308                   NaN  (Polo Petroquímico do Sul, Passo Raso, Triunfo...
# 92991                   NaN  (São Vítor, Governador Valadares, Microrregião...
# 95628                   NaN  (Sambaíba, Região Geográfica Imediata de Balsa...
# 99162                   NaN  (Palmeirinha, Unaí, Microrregião Unaí, Região ...

# %% [markdown]
# **Observation** : à priori, on remarque qu'une seule erreur à l'index 59563, car les coordonnées trouvées sont en France

# %% [markdown]
# Car c'est qu'une seule ligne, je la remplie à la main, en récupérant les coordonnées à https://www.coordonnees-gps.fr/

# %%
df_orders_cust_geoetranger.loc[59563,'geolocation_lat'] = -3.622443

# %%
df_orders_cust_geoetranger.loc[59563,'geolocation_lng'] = -39.821936

# %%
df_orders_cust_geoetranger.drop(['location'], axis=1, inplace=True)

# %%
df_orders_cust_geoetranger
# Out:
#                                    order_id                       customer_id  \
# old_index
# 445        690199d6a2c51ff57c6b392d7680cbfd  19bacb562bd43bd4eaf05b6c0a59dad0
# 681        1b00c4d80c81cdbc36487c96c6e92f07  6f392cfb40b84e0857b16c23c773aa31
# 5497       ae78d443f07cc7da4cb961f34f1bc6a8  aa4c5b95810a5d4b1bf2cc56e7d76cd6
# 6559       6c187a778a170f2bc6beac3979e3a81c  e37623a7c983c5174d5aea2aad30a080
# 7553       5050bad26c6099dce48e97368a53f149  f341549b5b28a46a5b4db2f4372e36a2
# 10699      7bac1567c0592387d6b83a189f7d25ef  4a5642b29f7d0885758928dc7ec35909
# 14006      7a36ddcacbdd80a7dd8771aa4c6e465e  e988b94fc82408ecac8299c744959c58
# 14664      2ee460773e708be4e0208745a3864b8c  3bd12f7c1ad3a3908905785e43de8603
# 17005      971e55ce6ef3eae4af8292bd71c8e27f  8a629de914739aa508711c4311abf537
# 17153      19b6861ce084842fb4ec0cafc59deebe  78a11bb1fa72f556996b9a5b9bcd0629
# 21025      15c73309f9a91be9baa4d58d1e02cbab  59365a596fafb5488c739ac1e657f6ab
# 24670      de5663895e88028a4c5a84d46b7475cc  c785e91c77b1e2fc9f642dbf170adbd4
# 25708      a389c8dd641e5e3bd97578e44f1ece83  7b0a3a430a7e8b6183eac952df55cb07
# 27154      30ee51f86a9d676801e824efd4aad215  c55a17a7c31353c35d48550b3aebc06f
# 27486      eca75747f628939976e814e7972bfea8  ce102f790bb667f9851019a3cb0ed958
# 27944      84a80b02b3af075990fc7d9d2369f066  f792e419335df11d82c32efcfb09c51b
# 67963               2017-04-24 00:00:00  c9d0b6cc7d9fccb750ba1cc6c4b76ecb
# 70065               2018-07-12 00:00:00  8b1ea5b8958ebfa320d33b80215dfbc6
# 70788               2018-06-21 00:00:00  e9a5ffad71fbb203da7c2661b647cc9a
# 71500               2018-04-18 00:00:00  924f226bd0426ed28ec908a135b18950
# 72041               2017-04-19 00:00:00  2f37a695478fbf531a61d086b444a634
# 72397               2017-11-29 00:00:00  d647bd6f2997e98e04f7d84da752b873
# 75034               2018-07-17 00:00:00  bfe6b5289dd1cec948d3714ae5453392
# 80750               2018-04-26 00:00:00  69b09832dc41358029209b44f47854ff
# 86802               2017-12-26 00:00:00  3858e59d2965f2cf2d49f28ea26ec172
# 87246               2017-12-14 00:00:00  3815e5fe3869fb75b982acc9da267b9f
# 88308               2018-03-23 00:00:00  b501aa16c4c71c55bd43d45d112bd135
# 92991               2017-10-20 00:00:00  cf717ffae55d20f545be20358a44f698
# 95628               2017-12-19 00:00:00  6c9871f7c55b411fabb59d9130b51e6d
# 99162               2017-03-27 00:00:00  04a5a9b154c83e4b19258dcd0e4476ed
#
#            customer_zip_code_prefix                 customer_city  \
# old_index
# 445                           87323                 alto sao joao
# 681                           28160                 santo eduardo
# 5497                          59299                 poco de pedra
# 6559                          83843                   doce grande
# 7553                           6930                    cipo-guacu
# 10699                         75784             domiciano ribeiro
# 14006                         29718              angelo frechiani
# 14664                         65137                        maioba
# 17005                         28575                    jaguarembe
# 17153                         55863                        siriji
# 21025                         28120                      ibitioca
# 24670                         36596             estevao de araujo
# 25708                         85894                  sao clemente
# 27154                         35408                        glaura
# 27486                         75784             domiciano ribeiro
# 27944                         28530      sao sebastiao do paraiba
# 31408                         36857                     pinhotiba
# 36615                         85118                   palmeirinha
# 38553                         28388         bom jesus do querendo
# 38613                         17390        sao sebastiao da serra
# 43578                         36248          conceicao do formoso
# 47177                         65137                        maioba
# 48101                         35242                   cuite velho
# 52868                         28160                 santo eduardo
# 54274                         86996          sao miguel do cambui
# 57090                         36956      sao francisco do humaita
# 57410                         58734                      passagem
# 57509                         25840                      bemposta
# 58357                         38710                   major porto
# 59563                         62625                         missi
# 61555                         95572                     mampituba
# 61841                         42843                          jaua
# 63762                         39103                        guinda
# 64560                         65137                        maioba
# 66852                          8980      nossa senhora do remedio
# 67963                         38627             palmital de minas
# 70065                         85958           perola independente
# 70788                         19740                          bora
# 71500                          8980      nossa senhora do remedio
# 72041                         44135                      humildes
# 72397                         28655                      monnerat
# 75034                         49870                         itabi
# 80750                         58286            pitanga de estrada
# 86802                         28655                      monnerat
# 87246                         48504                       aribice
# 88308                         95853  polo petroquimico de triunfo
# 92991                         35104                     sao vitor
# 95628                         65830                      sambaiba
# 99162                         85118                   palmeirinha
#
#           customer_state  geolocation_zip_code_prefix  old_index  \
# old_index
# 445                   PR                          NaN        445
# 681                   RJ                          NaN        681
# 5497                  RN                          NaN       5497
# 6559                  PR                          NaN       6559
# 7553                  SP                          NaN       7553
# 10699                 GO                          NaN      10699
# 14006                 ES                          NaN      14006
# 14664                 MA                          NaN      14664
# 17005                 RJ                          NaN      17005
# 17153                 PE                          NaN      17153
# 21025                 RJ                          NaN      21025
# 24670                 MG                          NaN      24670
# 25708                 PR                          NaN      25708
# 27154                 MG                          NaN      27154
# 27486                 GO                          NaN      27486
# 27944                 RJ                          NaN      27944
# 31408                 MG                          NaN      31408
# 36615                 PR                          NaN      36615
# 38553                 RJ                          NaN      38553
# 38613                 SP                          NaN      38613
# 43578                 MG                          NaN      43578
# 47177                 MA                          NaN      47177
# 48101                 MG                          NaN      48101
# 52868                 RJ                          NaN      52868
# 54274                 PR                          NaN      54274
# 57090                 MG                          NaN      57090
# 57410                 PB                          NaN      57410
# 57509                 RJ                          NaN      57509
# 58357                 MG                          NaN      58357
# 59563                 CE                          NaN      59563
# 61555                 RS                          NaN      61555
# 61841                 BA                          NaN      61841
# 63762                 MG                          NaN      63762
# 64560                 MA                          NaN      64560
# 66852                 SP                          NaN      66852
# 67963                 MG                          NaN      67963
# 70065                 PR                          NaN      70065
# 70788                 SP                          NaN      70788
# 71500                 SP                          NaN      71500
# 72041                 BA                          NaN      72041
# 72397                 RJ                          NaN      72397
# 75034                 SE                          NaN      75034
# 80750                 PB                          NaN      80750
# 86802                 RJ                          NaN      86802
# 87246                 BA                          NaN      87246
# 88308                 RS                          NaN      88308
# 92991                 MG                          NaN      92991
# 95628                 MA                          NaN      95628
# 99162                 PR                          NaN      99162
#
#           geolocation_city  geolocation_lat  geolocation_lng geolocation_state
# old_index
# 445                    NaN       -16.715183       -43.854449               NaN
# 681                    NaN       -21.214826       -41.467473               NaN
# 5497                   NaN        -9.045909       -41.033095               NaN
# 6559                   NaN       -26.022387       -49.430872               NaN
# 7553                   NaN       -23.857032       -46.792861               NaN
# 10699                  NaN       -16.920938       -47.707508               NaN
# 14006                  NaN       -19.304460       -40.668167               NaN
# 14664                  NaN        -2.523879       -44.178247               NaN
# 17005                  NaN       -21.724840       -41.992431               NaN
# 17153                  NaN        -7.640620       -35.483097               NaN
# 21025                  NaN       -21.823715       -41.474154               NaN
# 24670                  NaN       -20.623000       -42.481557               NaN
# 25708                  NaN        37.137052        -7.998247               NaN
# 27154                  NaN       -20.288617       -43.647888               NaN
# 27486                  NaN       -16.920938       -47.707508               NaN
# 27944                  NaN       -21.754551       -42.371079               NaN
# 31408                  NaN       -20.962644       -42.196969               NaN
# 36615                  NaN       -16.023210       -46.841828               NaN
# 38553                  NaN       -20.981641       -41.849826               NaN
# 38613                  NaN       -22.442616       -48.010787               NaN
# 43578                  NaN       -21.405593       -43.368606               NaN
# 47177                  NaN        -2.523879       -44.178247               NaN
# 48101                  NaN       -19.268734       -41.639108               NaN
# 52868                  NaN       -21.214826       -41.467473               NaN
# 54274                  NaN       -23.610591       -51.859848               NaN
# 57090                  NaN       -20.037494       -41.359003               NaN
# 57410                  NaN        -7.136448       -37.047429               NaN
# 57509                  NaN        41.314343        -6.501298               NaN
# 58357                  NaN       -18.617159       -46.050132               NaN
# 59563                  NaN        -3.622443       -39.821936               NaN
# 61555                  NaN       -29.212823       -49.934453               NaN
# 61841                  NaN       -15.895928        37.830233               NaN
# 63762                  NaN       -18.281855       -43.728092               NaN
# 64560                  NaN        -2.523879       -44.178247               NaN
# 66852                  NaN       -23.538370       -45.936891               NaN
# 67963                  NaN       -16.098210       -47.246724               NaN
# 70065                  NaN       -24.533252       -53.743050               NaN
# 70788                  NaN       -22.270335       -50.544267               NaN
# 71500                  NaN       -23.538370       -45.936891               NaN
# 72041                  NaN       -12.348500       -38.887975               NaN
# 72397                  NaN       -22.083194       -42.413072               NaN
# 75034                  NaN       -10.126341       -37.101757               NaN
# 80750                  NaN        -7.948433       -35.139833               NaN
# 86802                  NaN       -22.083194       -42.413072               NaN
# 87246                  NaN       -10.566165       -38.799366               NaN
# 88308                  NaN       -29.875161       -51.390547               NaN
# 92991                  NaN       -18.725461       -41.732008               NaN
# 95628                  NaN        -7.134473       -45.351506               NaN
# 99162                  NaN       -16.023210       -46.841828               NaN

# %%
#  liste de l'index des lignes où la latitude contient NaN
index_geonull = df_orders_cust_geofilledna[df_orders_cust_geofilledna['geolocation_lat'].isna()].index

# %%
df_orders_cust_geofilledna.loc[index_geonull, 'geolocation_lat'] = df_orders_cust_geoetranger['geolocation_lat']

# %%
df_orders_cust_geofilledna
# Out:
#                                    order_id                       customer_id  \
# old_index
# 445        690199d6a2c51ff57c6b392d7680cbfd  19bacb562bd43bd4eaf05b6c0a59dad0
# 610        9f2da077d2d1eb6e8abcacef8776e941  2386792ff4818fe030a3b1364994f51e
# 681        1b00c4d80c81cdbc36487c96c6e92f07  6f392cfb40b84e0857b16c23c773aa31
# 926        7ebe19943d85e81a7b0eb108681276b7  fa3a8736d5ae8f7df9b0a4154d0b14dc
# 1091       d0bec96aad189992b278688279ba1511  f4302056f0c58570522590f8181de2c7
# ...                                     ...                               ...
# 97935      75f6ded14ff770cff5dab61532421db4  bbf5e98dabf1bdac752afc68f8032bda
# 98886      da47f3e1d422ef0acfa45d3a81f0085f  d14b76c93d237241c52e0e6767feb42a
# 99062      1a0e54c67a7d784f932f5cc4f953fbaf  baca33004aa726524d5a891853100559
# 99162      e1d102f12364768054a07dfa10fc43cc  f58c14ad1417ae5e8f9c6d0f9f6aec24
# 99217      2fe782855de414d2c2c51fcdb1437e3c  626a0f18050903535ecf8e312a5c028f
#
#           order_status order_purchase_timestamp    order_approved_at  \
# old_index
# 445          delivered      2018-03-16 11:31:18  2018-03-16 11:49:14
# 610          delivered      2017-10-28 21:26:26  2017-10-28 21:46:29
# 681          delivered      2017-05-14 09:36:36  2017-05-16 03:22:50
# 926          delivered      2018-07-22 10:28:14  2018-07-23 11:31:43
# 1091         delivered      2018-05-08 21:04:16  2018-05-08 21:15:28
# ...                ...                      ...                  ...
# 97935        delivered      2018-04-03 08:37:21  2018-04-03 08:50:14
# 98886        delivered      2017-12-04 21:53:42  2017-12-05 10:30:46
# 99062        delivered      2017-06-16 21:56:39  2017-06-16 22:06:26
# 99162        delivered      2017-03-05 22:11:02  2017-03-05 22:25:16
# 99217        delivered      2018-08-01 07:13:41  2018-08-01 07:44:03
#
#           order_delivered_carrier_date order_delivered_customer_date  \
# old_index
# 445                2018-03-19 19:56:23           2018-05-14 12:28:56
# 610                2017-11-06 11:08:52           2017-11-13 22:33:12
# 681                2017-05-16 12:05:28           2017-05-23 07:52:33
# 926                2018-07-23 10:09:00           2018-07-26 16:42:42
# 1091               2018-05-10 18:29:00           2018-05-21 13:06:35
# ...                                ...                           ...
# 97935              2018-04-04 19:28:19           2018-05-07 22:54:47
# 98886              2017-12-06 16:58:51           2017-12-19 16:23:35
# 99062              2017-06-20 15:30:45           2017-07-03 08:49:44
# 99162              2017-03-06 09:38:29           2017-03-23 15:06:37
# 99217              2018-08-03 04:29:00           2018-08-10 21:46:42
#
#           order_estimated_delivery_date                customer_unique_id  \
# old_index
# 445                 2018-04-11 00:00:00  c5f01991eadc43c924dfd891e9026217
# 610                 2017-11-22 00:00:00  ab7bed4092cc3dadbaefba86cb45f37f
# 681                 2017-06-02 00:00:00  5399c9213ca365a480537a1b21423d2c
# 926                 2018-08-15 00:00:00  2de521d3fd097acfbd5bed9c7b9ed0d0
# 1091                2018-06-05 00:00:00  67b05b597a66b5c449025000b9430abb
# ...                                 ...                               ...
# 97935               2018-04-20 00:00:00  13aba123512eef450a11646c572fccca
# 98886               2018-01-02 00:00:00  4a88a750280bdba0dd1f167ae2b68bfd
# 99062               2017-07-13 00:00:00  aa67457bb07fde4e952d67b038135bee
# 99162               2017-03-27 00:00:00  04a5a9b154c83e4b19258dcd0e4476ed
# 99217               2018-08-23 00:00:00  615eb18afcde37c5ed09c9d4109c41fa
#
#            customer_zip_code_prefix  customer_city customer_state  \
# old_index
# 445                           87323  alto sao joao             PR
# 610                           73081       brasilia             DF
# 681                           28160  santo eduardo             RJ
# 926                           71551       brasilia             DF
# 1091                          64605          picos             PI
# ...                             ...            ...            ...
# 97935                         29949     sao mateus             ES
# 98886                         71919       brasilia             DF
# 99062                         73369       brasilia             DF
# 99162                         85118    palmeirinha             PR
# 99217                         56327      petrolina             PE
#
#            geolocation_zip_code_prefix  old_index geolocation_city  \
# old_index
# 445                                NaN        445              NaN
# 610                                NaN        610         brasilia
# 681                                NaN        681              NaN
# 926                                NaN        926         brasilia
# 1091                               NaN       1091            picos
# ...                                ...        ...              ...
# 97935                              NaN      97935       sao mateus
# 98886                              NaN      98886         brasilia
# 99062                              NaN      99062         brasilia
# 99162                              NaN      99162              NaN
# 99217                              NaN      99217        petrolina
#
#            geolocation_lat  geolocation_lng geolocation_state
# old_index
# 445             -16.715183              NaN               NaN
# 610             -15.820008       -47.979953                DF
# 681             -21.214826              NaN               NaN
# 926             -15.820008       -47.979953                DF
# 1091             -7.083213       -41.468344                PI
# ...                    ...              ...               ...
# 97935           -18.719300       -39.855049                ES
# 98886           -15.820008       -47.979953                DF
# 99062           -15.820008       -47.979953                DF
# 99162           -16.023210              NaN               NaN
# 99217            -9.385096       -40.501313                PE
#
# [278 rows x 18 columns]

# %%
df_orders_cust_geofilledna['geolocation_lat'].isna().sum()
# Out:
# 0

# %%
df_orders_cust_geofilledna.loc[index_geonull, 'geolocation_lng'] = df_orders_cust_geoetranger['geolocation_lng']

# %%
df_orders_cust_geofilledna['geolocation_lng'].isna().sum()
# Out:
# 0

# %%
df_orders_cust_geofilledna
# Out:
#                                    order_id                       customer_id  \
# old_index
# 445        690199d6a2c51ff57c6b392d7680cbfd  19bacb562bd43bd4eaf05b6c0a59dad0
# 610        9f2da077d2d1eb6e8abcacef8776e941  2386792ff4818fe030a3b1364994f51e
# 681        1b00c4d80c81cdbc36487c96c6e92f07  6f392cfb40b84e0857b16c23c773aa31
# 926        7ebe19943d85e81a7b0eb108681276b7  fa3a8736d5ae8f7df9b0a4154d0b14dc
# 1091       d0bec96aad189992b278688279ba1511  f4302056f0c58570522590f8181de2c7
# ...                                     ...                               ...
# 97935      75f6ded14ff770cff5dab61532421db4  bbf5e98dabf1bdac752afc68f8032bda
# 98886      da47f3e1d422ef0acfa45d3a81f0085f  d14b76c93d237241c52e0e6767feb42a
# 99062      1a0e54c67a7d784f932f5cc4f953fbaf  baca33004aa726524d5a891853100559
# 99162      e1d102f12364768054a07dfa10fc43cc  f58c14ad1417ae5e8f9c6d0f9f6aec24
# 99217      2fe782855de414d2c2c51fcdb1437e3c  626a0f18050903535ecf8e312a5c028f
#
#           order_status order_purchase_timestamp    order_approved_at  \
# old_index
# 445          delivered      2018-03-16 11:31:18  2018-03-16 11:49:14
# 610          delivered      2017-10-28 21:26:26  2017-10-28 21:46:29
# 681          delivered      2017-05-14 09:36:36  2017-05-16 03:22:50
# 926          delivered      2018-07-22 10:28:14  2018-07-23 11:31:43
# 1091         delivered      2018-05-08 21:04:16  2018-05-08 21:15:28
# ...                ...                      ...                  ...
# 97935        delivered      2018-04-03 08:37:21  2018-04-03 08:50:14
# 98886        delivered      2017-12-04 21:53:42  2017-12-05 10:30:46
# 99062        delivered      2017-06-16 21:56:39  2017-06-16 22:06:26
# 99162        delivered      2017-03-05 22:11:02  2017-03-05 22:25:16
# 99217        delivered      2018-08-01 07:13:41  2018-08-01 07:44:03
#
#           order_delivered_carrier_date order_delivered_customer_date  \
# old_index
# 445                2018-03-19 19:56:23           2018-05-14 12:28:56
# 610                2017-11-06 11:08:52           2017-11-13 22:33:12
# 681                2017-05-16 12:05:28           2017-05-23 07:52:33
# 926                2018-07-23 10:09:00           2018-07-26 16:42:42
# 1091               2018-05-10 18:29:00           2018-05-21 13:06:35
# ...                                ...                           ...
# 97935              2018-04-04 19:28:19           2018-05-07 22:54:47
# 98886              2017-12-06 16:58:51           2017-12-19 16:23:35
# 99062              2017-06-20 15:30:45           2017-07-03 08:49:44
# 99162              2017-03-06 09:38:29           2017-03-23 15:06:37
# 99217              2018-08-03 04:29:00           2018-08-10 21:46:42
#
#           order_estimated_delivery_date                customer_unique_id  \
# old_index
# 445                 2018-04-11 00:00:00  c5f01991eadc43c924dfd891e9026217
# 610                 2017-11-22 00:00:00  ab7bed4092cc3dadbaefba86cb45f37f
# 681                 2017-06-02 00:00:00  5399c9213ca365a480537a1b21423d2c
# 926                 2018-08-15 00:00:00  2de521d3fd097acfbd5bed9c7b9ed0d0
# 1091                2018-06-05 00:00:00  67b05b597a66b5c449025000b9430abb
# ...                                 ...                               ...
# 97935               2018-04-20 00:00:00  13aba123512eef450a11646c572fccca
# 98886               2018-01-02 00:00:00  4a88a750280bdba0dd1f167ae2b68bfd
# 99062               2017-07-13 00:00:00  aa67457bb07fde4e952d67b038135bee
# 99162               2017-03-27 00:00:00  04a5a9b154c83e4b19258dcd0e4476ed
# 99217               2018-08-23 00:00:00  615eb18afcde37c5ed09c9d4109c41fa
#
#            customer_zip_code_prefix  customer_city customer_state  \
# old_index
# 445                           87323  alto sao joao             PR
# 610                           73081       brasilia             DF
# 681                           28160  santo eduardo             RJ
# 926                           71551       brasilia             DF
# 1091                          64605          picos             PI
# ...                             ...            ...            ...
# 97935                         29949     sao mateus             ES
# 98886                         71919       brasilia             DF
# 99062                         73369       brasilia             DF
# 99162                         85118    palmeirinha             PR
# 99217                         56327      petrolina             PE
#
#            geolocation_zip_code_prefix  old_index geolocation_city  \
# old_index
# 445                                NaN        445              NaN
# 610                                NaN        610         brasilia
# 681                                NaN        681              NaN
# 926                                NaN        926         brasilia
# 1091                               NaN       1091            picos
# ...                                ...        ...              ...
# 97935                              NaN      97935       sao mateus
# 98886                              NaN      98886         brasilia
# 99062                              NaN      99062         brasilia
# 99162                              NaN      99162              NaN
# 99217                              NaN      99217        petrolina
#
#            geolocation_lat  geolocation_lng geolocation_state
# old_index
# 445             -16.715183       -43.854449               NaN
# 610             -15.820008       -47.979953                DF
# 681             -21.214826       -41.467473               NaN
# 926             -15.820008       -47.979953                DF
# 1091             -7.083213       -41.468344                PI
# ...                    ...              ...               ...
# 97935           -18.719300       -39.855049                ES
# 98886           -15.820008       -47.979953                DF
# 99062           -15.820008       -47.979953                DF
# 99162           -16.023210       -46.841828               NaN
# 99217            -9.385096       -40.501313                PE
#
# [278 rows x 18 columns]

# %% [markdown]
# La dataframe *df_orders_cust_geofilledna* ne contient plus de NaN dans les colonnes *geolocation_lat* et *geolocation_lng*

# %%
df_orders_cust_geofilledna.shape
# Out:
# (278, 18)

# %%
df_olist_orders_customers_geo['geolocation_lat'].isna().sum()
# Out:
# 278

# %%
df_olist_orders_customers_geo['geolocation_lng'].isna().sum()
# Out:
# 278

# %%
#  liste de l'index des lignes où la latitude contient NaN dans le dataframe 'df_olist_orders_customers_geo'
index_df_olist_geonull = df_olist_orders_customers_geo[df_olist_orders_customers_geo['geolocation_lat'].isna()].index

# %%
index_df_olist_geonull
# Out:
# Int64Index([  445,   610,   681,   926,  1091,  1202,  1343,  2004,  2344,
#              2495,
#             ...
#             92991, 94493, 95336, 95628, 95962, 97935, 98886, 99062, 99162,
#             99217],
#            dtype='int64', length=278)

# %%
df_orders_cust_geofilledna.index
# Out:
# Int64Index([  445,   610,   681,   926,  1091,  1202,  1343,  2004,  2344,
#              2495,
#             ...
#             92991, 94493, 95336, 95628, 95962, 97935, 98886, 99062, 99162,
#             99217],
#            dtype='int64', name='old_index', length=278)

# %%
df_ord_cust_geo.loc[index_df_olist_geonull, 'geolocation_lat'] = df_orders_cust_geofilledna['geolocation_lat']

# %%
df_ord_cust_geo.loc[index_df_olist_geonull, 'geolocation_lng'] = df_orders_cust_geofilledna['geolocation_lng']

# %%
df_ord_cust_geo['geolocation_lat'].isna().sum()
# Out:
# 0

# %%
df_ord_cust_geo['geolocation_lng'].isna().sum()
# Out:
# 0

# %%
df_ord_cust_geo.shape
# Out:
# (99441, 17)

# %%
df_ord_cust_geo
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# 0        delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1        delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2        delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3        delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4        delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
# ...            ...                      ...                  ...
# 99436    delivered      2017-03-09 09:54:05  2017-03-09 09:54:05
# 99437    delivered      2018-02-06 12:58:58  2018-02-06 13:10:37
# 99438    delivered      2017-08-27 14:46:43  2017-08-27 15:04:16
# 99439    delivered      2018-01-08 21:28:27  2018-01-08 21:36:21
# 99440    delivered      2018-03-08 20:57:30  2018-03-09 11:20:28
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 0              2017-10-04 19:55:00           2017-10-10 21:25:13
# 1              2018-07-26 14:31:00           2018-08-07 15:27:45
# 2              2018-08-08 13:50:00           2018-08-17 18:06:29
# 3              2017-11-22 13:39:59           2017-12-02 00:28:42
# 4              2018-02-14 19:46:34           2018-02-16 18:17:02
# ...                            ...                           ...
# 99436          2017-03-10 11:18:03           2017-03-17 15:08:01
# 99437          2018-02-07 23:22:42           2018-02-28 17:37:56
# 99438          2017-08-28 20:52:26           2017-09-21 11:24:17
# 99439          2018-01-12 15:35:03           2018-01-25 23:32:54
# 99440          2018-03-09 22:11:59           2018-03-16 13:08:30
#
#       order_estimated_delivery_date                customer_unique_id  \
# 0               2017-10-18 00:00:00  7c396fd4830fd04220f754e42b4e5bff
# 1               2018-08-13 00:00:00  af07308b275d755c9edb36a90c618231
# 2               2018-09-04 00:00:00  3a653a41f6f9fc3d2a113cf8398680e8
# 3               2017-12-15 00:00:00  7c142cf63193a1473d2e66489a9ae977
# 4               2018-02-26 00:00:00  72632f0f9dd73dfee390c9b22eb56dd6
# ...                             ...                               ...
# 99436           2017-03-28 00:00:00  6359f309b166b0196dbf7ad2ac62bb5a
# 99437           2018-03-02 00:00:00  da62f9e57a76d978d02ab5362c509660
# 99438           2017-09-27 00:00:00  737520a9aad80b3fbbdad19b66b37b30
# 99439           2018-02-15 00:00:00  5097a5312c8b157bb7be58ae360ef43c
# 99440           2018-04-03 00:00:00  60350aa974b26ff12caad89e55993bd6
#
#        customer_zip_code_prefix            customer_city customer_state  \
# 0                          3149                sao paulo             SP
# 1                         47813                barreiras             BA
# 2                         75265               vianopolis             GO
# 3                         59296  sao goncalo do amarante             RN
# 4                          9195              santo andre             SP
# ...                         ...                      ...            ...
# 99436                     12209      sao jose dos campos             SP
# 99437                     11722             praia grande             SP
# 99438                     45920              nova vicosa             BA
# 99439                     28685                  japuiba             RJ
# 99440                     83750                     lapa             PR
#
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                           3149.0       -23.575816       -46.587303
# 1                          47813.0       -12.126533       -45.008244
# 2                          75265.0       -16.744472       -48.514624
# 3                          59296.0        -5.773971       -35.273838
# 4                           9195.0       -23.675471       -46.514788
# ...                            ...              ...              ...
# 99436                      12209.0       -23.177048       -45.884506
# 99437                      11722.0       -24.001467       -46.449577
# 99438                      45920.0       -17.897354       -39.372100
# 99439                      28685.0       -22.562040       -42.690186
# 99440                      83750.0       -25.766121       -49.720209
#
#               geolocation_city geolocation_state
# 0                    são paulo                SP
# 1                    barreiras                BA
# 2                   vianopolis                GO
# 3      são gonçalo do amarante                RN
# 4                  santo andre                SP
# ...                        ...               ...
# 99436      sao jose dos campos                SP
# 99437             praia grande                SP
# 99438              nova vicosa                BA
# 99439                  japuiba                RJ
# 99440                     lapa                PR
#
# [99441 rows x 17 columns]

# %%
df_ord_cust_geo.drop(['geolocation_zip_code_prefix', 'geolocation_city', 'geolocation_state'], axis=1, inplace=True)

# %%
df_ord_cust_geo.rename(columns={"geolocation_lat": "customer_lat", "geolocation_lng": "customer_lng"}, inplace = True)

# %%
df_ord_cust_geo
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# 0        delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1        delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2        delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3        delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4        delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
# ...            ...                      ...                  ...
# 99436    delivered      2017-03-09 09:54:05  2017-03-09 09:54:05
# 99437    delivered      2018-02-06 12:58:58  2018-02-06 13:10:37
# 99438    delivered      2017-08-27 14:46:43  2017-08-27 15:04:16
# 99439    delivered      2018-01-08 21:28:27  2018-01-08 21:36:21
# 99440    delivered      2018-03-08 20:57:30  2018-03-09 11:20:28
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 0              2017-10-04 19:55:00           2017-10-10 21:25:13
# 1              2018-07-26 14:31:00           2018-08-07 15:27:45
# 2              2018-08-08 13:50:00           2018-08-17 18:06:29
# 3              2017-11-22 13:39:59           2017-12-02 00:28:42
# 4              2018-02-14 19:46:34           2018-02-16 18:17:02
# ...                            ...                           ...
# 99436          2017-03-10 11:18:03           2017-03-17 15:08:01
# 99437          2018-02-07 23:22:42           2018-02-28 17:37:56
# 99438          2017-08-28 20:52:26           2017-09-21 11:24:17
# 99439          2018-01-12 15:35:03           2018-01-25 23:32:54
# 99440          2018-03-09 22:11:59           2018-03-16 13:08:30
#
#       order_estimated_delivery_date                customer_unique_id  \
# 0               2017-10-18 00:00:00  7c396fd4830fd04220f754e42b4e5bff
# 1               2018-08-13 00:00:00  af07308b275d755c9edb36a90c618231
# 2               2018-09-04 00:00:00  3a653a41f6f9fc3d2a113cf8398680e8
# 3               2017-12-15 00:00:00  7c142cf63193a1473d2e66489a9ae977
# 4               2018-02-26 00:00:00  72632f0f9dd73dfee390c9b22eb56dd6
# ...                             ...                               ...
# 99436           2017-03-28 00:00:00  6359f309b166b0196dbf7ad2ac62bb5a
# 99437           2018-03-02 00:00:00  da62f9e57a76d978d02ab5362c509660
# 99438           2017-09-27 00:00:00  737520a9aad80b3fbbdad19b66b37b30
# 99439           2018-02-15 00:00:00  5097a5312c8b157bb7be58ae360ef43c
# 99440           2018-04-03 00:00:00  60350aa974b26ff12caad89e55993bd6
#
#        customer_zip_code_prefix            customer_city customer_state  \
# 0                          3149                sao paulo             SP
# 1                         47813                barreiras             BA
# 2                         75265               vianopolis             GO
# 3                         59296  sao goncalo do amarante             RN
# 4                          9195              santo andre             SP
# ...                         ...                      ...            ...
# 99436                     12209      sao jose dos campos             SP
# 99437                     11722             praia grande             SP
# 99438                     45920              nova vicosa             BA
# 99439                     28685                  japuiba             RJ
# 99440                     83750                     lapa             PR
#
#        customer_lat  customer_lng
# 0        -23.575816    -46.587303
# 1        -12.126533    -45.008244
# 2        -16.744472    -48.514624
# 3         -5.773971    -35.273838
# 4        -23.675471    -46.514788
# ...             ...           ...
# 99436    -23.177048    -45.884506
# 99437    -24.001467    -46.449577
# 99438    -17.897354    -39.372100
# 99439    -22.562040    -42.690186
# 99440    -25.766121    -49.720209
#
# [99441 rows x 14 columns]

# %% [markdown]
# ![Le schéma des données](scheme_etape_2.png)

# %% [markdown]
# # Etape 3 de merge <a class="anchor" id="merge3"></a>

# %% [markdown]
# ### Merge de *df_ord_cust_geo* avec *df_olist_order_items*

# %%
df_ord_cust_geo
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# 0        delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1        delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2        delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3        delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4        delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
# ...            ...                      ...                  ...
# 99436    delivered      2017-03-09 09:54:05  2017-03-09 09:54:05
# 99437    delivered      2018-02-06 12:58:58  2018-02-06 13:10:37
# 99438    delivered      2017-08-27 14:46:43  2017-08-27 15:04:16
# 99439    delivered      2018-01-08 21:28:27  2018-01-08 21:36:21
# 99440    delivered      2018-03-08 20:57:30  2018-03-09 11:20:28
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 0              2017-10-04 19:55:00           2017-10-10 21:25:13
# 1              2018-07-26 14:31:00           2018-08-07 15:27:45
# 2              2018-08-08 13:50:00           2018-08-17 18:06:29
# 3              2017-11-22 13:39:59           2017-12-02 00:28:42
# 4              2018-02-14 19:46:34           2018-02-16 18:17:02
# ...                            ...                           ...
# 99436          2017-03-10 11:18:03           2017-03-17 15:08:01
# 99437          2018-02-07 23:22:42           2018-02-28 17:37:56
# 99438          2017-08-28 20:52:26           2017-09-21 11:24:17
# 99439          2018-01-12 15:35:03           2018-01-25 23:32:54
# 99440          2018-03-09 22:11:59           2018-03-16 13:08:30
#
#       order_estimated_delivery_date                customer_unique_id  \
# 0               2017-10-18 00:00:00  7c396fd4830fd04220f754e42b4e5bff
# 1               2018-08-13 00:00:00  af07308b275d755c9edb36a90c618231
# 2               2018-09-04 00:00:00  3a653a41f6f9fc3d2a113cf8398680e8
# 3               2017-12-15 00:00:00  7c142cf63193a1473d2e66489a9ae977
# 4               2018-02-26 00:00:00  72632f0f9dd73dfee390c9b22eb56dd6
# ...                             ...                               ...
# 99436           2017-03-28 00:00:00  6359f309b166b0196dbf7ad2ac62bb5a
# 99437           2018-03-02 00:00:00  da62f9e57a76d978d02ab5362c509660
# 99438           2017-09-27 00:00:00  737520a9aad80b3fbbdad19b66b37b30
# 99439           2018-02-15 00:00:00  5097a5312c8b157bb7be58ae360ef43c
# 99440           2018-04-03 00:00:00  60350aa974b26ff12caad89e55993bd6
#
#        customer_zip_code_prefix            customer_city customer_state  \
# 0                          3149                sao paulo             SP
# 1                         47813                barreiras             BA
# 2                         75265               vianopolis             GO
# 3                         59296  sao goncalo do amarante             RN
# 4                          9195              santo andre             SP
# ...                         ...                      ...            ...
# 99436                     12209      sao jose dos campos             SP
# 99437                     11722             praia grande             SP
# 99438                     45920              nova vicosa             BA
# 99439                     28685                  japuiba             RJ
# 99440                     83750                     lapa             PR
#
#        customer_lat  customer_lng
# 0        -23.575816    -46.587303
# 1        -12.126533    -45.008244
# 2        -16.744472    -48.514624
# 3         -5.773971    -35.273838
# 4        -23.675471    -46.514788
# ...             ...           ...
# 99436    -23.177048    -45.884506
# 99437    -24.001467    -46.449577
# 99438    -17.897354    -39.372100
# 99439    -22.562040    -42.690186
# 99440    -25.766121    -49.720209
#
# [99441 rows x 14 columns]

# %%
# df_olist_orders_customers.merge(df_geo_agg, how='left', left_on='customer_zip_code_prefix', right_on='geolocation_zip_code_prefix')
df_orders_cust_geo_orderitems = df_ord_cust_geo.merge(df_olist_order_items, how='left', on = 'order_id')

# %%
df_orders_cust_geo_orderitems.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 113425 entries, 0 to 113424
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       113425 non-null  object
#  1   customer_id                    113425 non-null  object
#  2   order_status                   113425 non-null  object
#  3   order_purchase_timestamp       113425 non-null  object
#  4   order_approved_at              113264 non-null  object
#  5   order_delivered_carrier_date   111457 non-null  object
#  6   order_delivered_customer_date  110196 non-null  object
#  7   order_estimated_delivery_date  113425 non-null  object
#  8   customer_unique_id             113425 non-null  object
#  9   customer_zip_code_prefix       113425 non-null  int64
#  10  customer_city                  113425 non-null  object
#  11  customer_state                 113425 non-null  object
#  12  customer_lat                   113425 non-null  float64
#  13  customer_lng                   113425 non-null  float64
#  14  order_item_id                  112650 non-null  float64
#  15  product_id                     112650 non-null  object
#  16  seller_id                      112650 non-null  object
#  17  shipping_limit_date            112650 non-null  object
#  18  price                          112650 non-null  float64
#  19  freight_value                  112650 non-null  float64
# dtypes: float64(5), int64(1), object(14)
# memory usage: 18.2+ MB

# %%
df_orders_cust_geo_orderitems
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 113420  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 113421  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 113422  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 113423  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 113424  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# 0         delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1         delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2         delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3         delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4         delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
# ...             ...                      ...                  ...
# 113420    delivered      2018-02-06 12:58:58  2018-02-06 13:10:37
# 113421    delivered      2017-08-27 14:46:43  2017-08-27 15:04:16
# 113422    delivered      2018-01-08 21:28:27  2018-01-08 21:36:21
# 113423    delivered      2018-01-08 21:28:27  2018-01-08 21:36:21
# 113424    delivered      2018-03-08 20:57:30  2018-03-09 11:20:28
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# 0               2017-10-04 19:55:00           2017-10-10 21:25:13
# 1               2018-07-26 14:31:00           2018-08-07 15:27:45
# 2               2018-08-08 13:50:00           2018-08-17 18:06:29
# 3               2017-11-22 13:39:59           2017-12-02 00:28:42
# 4               2018-02-14 19:46:34           2018-02-16 18:17:02
# ...                             ...                           ...
# 113420          2018-02-07 23:22:42           2018-02-28 17:37:56
# 113421          2017-08-28 20:52:26           2017-09-21 11:24:17
# 113422          2018-01-12 15:35:03           2018-01-25 23:32:54
# 113423          2018-01-12 15:35:03           2018-01-25 23:32:54
# 113424          2018-03-09 22:11:59           2018-03-16 13:08:30
#
#        order_estimated_delivery_date                customer_unique_id  \
# 0                2017-10-18 00:00:00  7c396fd4830fd04220f754e42b4e5bff
# 1                2018-08-13 00:00:00  af07308b275d755c9edb36a90c618231
# 2                2018-09-04 00:00:00  3a653a41f6f9fc3d2a113cf8398680e8
# 3                2017-12-15 00:00:00  7c142cf63193a1473d2e66489a9ae977
# 4                2018-02-26 00:00:00  72632f0f9dd73dfee390c9b22eb56dd6
# ...                              ...                               ...
# 113420           2018-03-02 00:00:00  da62f9e57a76d978d02ab5362c509660
# 113421           2017-09-27 00:00:00  737520a9aad80b3fbbdad19b66b37b30
# 113422           2018-02-15 00:00:00  5097a5312c8b157bb7be58ae360ef43c
# 113423           2018-02-15 00:00:00  5097a5312c8b157bb7be58ae360ef43c
# 113424           2018-04-03 00:00:00  60350aa974b26ff12caad89e55993bd6
#
#         customer_zip_code_prefix            customer_city customer_state  \
# 0                           3149                sao paulo             SP
# 1                          47813                barreiras             BA
# 2                          75265               vianopolis             GO
# 3                          59296  sao goncalo do amarante             RN
# 4                           9195              santo andre             SP
# ...                          ...                      ...            ...
# 113420                     11722             praia grande             SP
# 113421                     45920              nova vicosa             BA
# 113422                     28685                  japuiba             RJ
# 113423                     28685                  japuiba             RJ
# 113424                     83750                     lapa             PR
#
#         customer_lat  customer_lng  order_item_id  \
# 0         -23.575816    -46.587303            1.0
# 1         -12.126533    -45.008244            1.0
# 2         -16.744472    -48.514624            1.0
# 3          -5.773971    -35.273838            1.0
# 4         -23.675471    -46.514788            1.0
# ...              ...           ...            ...
# 113420    -24.001467    -46.449577            1.0
# 113421    -17.897354    -39.372100            1.0
# 113422    -22.562040    -42.690186            1.0
# 113423    -22.562040    -42.690186            2.0
# 113424    -25.766121    -49.720209            1.0
#
#                               product_id                         seller_id  \
# 0       87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9
# 1       595fac2a385ac33a80bd5114aec74eb8  289cdb325fb7e7f891c38608bf9e0962
# 2       aa4383b373c6aca5d8797843e5594415  4869f7a5dfa277a7dca6462dcf3b52b2
# 3       d0b61bfb1de832b15ba9d266ca96e5b0  66922902710d126a0e7d26b0e3805106
# 4       65266b2da20d04dbe00c5c2d3bb7859e  2c9e548be18521d1c43cde1c582c6de8
# ...                                  ...                               ...
# 113420  f1d4ce8c6dd66c47bbaa8c6781c2a923  1f9ab4708f3056ede07124aad39a2554
# 113421  b80910977a37536adeddd63663f916ad  d50d79cb34e38265a8649c383dcffd48
# 113422  d1c427060a0f73f6b889a5c7c61f2ac4  a1043bafd471dff536d0c462352beb48
# 113423  d1c427060a0f73f6b889a5c7c61f2ac4  a1043bafd471dff536d0c462352beb48
# 113424  006619bbed68b000c8ba3f8725d5409e  ececbfcff9804a2d6b40f589df8eef2b
#
#         shipping_limit_date   price  freight_value
# 0       2017-10-06 11:07:15   29.99           8.72
# 1       2018-07-30 03:24:27  118.70          22.76
# 2       2018-08-13 08:55:23  159.90          19.22
# 3       2017-11-23 19:45:59   45.00          27.20
# 4       2018-02-19 20:31:37   19.90           8.72
# ...                     ...     ...            ...
# 113420  2018-02-12 13:10:37  174.90          20.10
# 113421  2017-09-05 15:04:16  205.99          65.02
# 113422  2018-01-12 21:36:21  179.99          40.59
# 113423  2018-01-12 21:36:21  179.99          40.59
# 113424  2018-03-15 10:55:42   68.50          18.36
#
# [113425 rows x 20 columns]

# %%
df_orders_cust_geo_orderitems.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 161
# order_delivered_carrier_date     1968
# order_delivered_customer_date    3229
# order_estimated_delivery_date       0
# customer_unique_id                  0
# customer_zip_code_prefix            0
# customer_city                       0
# customer_state                      0
# customer_lat                        0
# customer_lng                        0
# order_item_id                     775
# product_id                        775
# seller_id                         775
# shipping_limit_date               775
# price                             775
# freight_value                     775
# dtype: int64

# %%
df_orders_cust_geo_orderitems[df_orders_cust_geo_orderitems['order_item_id'].isna()]['order_status'].unique()
# Out:
# array(['unavailable', 'canceled', 'created', 'shipped', 'invoiced'],
#       dtype=object)

# %%
df_orders_cust_geo_orderitems.groupby('customer_id').agg({'order_id':'count'}).max()
# Out:
# order_id    21
# dtype: int64

# %%
df_orders_cust_geo_orderitems.groupby('customer_unique_id').agg({'order_id':'count'}).max()
# Out:
# order_id    24
# dtype: int64

# %%
df_orders_cust_geo_orderitems.groupby('customer_unique_id').agg({'customer_id':'count'}).max()
# Out:
# customer_id    24
# dtype: int64

# %%
df_orders_cust_geo_orderitems.groupby('customer_id').agg({'customer_unique_id':'count'}).max()
# Out:
# customer_unique_id    21
# dtype: int64

# %% [markdown]
# ![Le schéma des données](scheme_etape_3.png)

# %% [markdown]
# # Etape 4 de merge <a class="anchor" id="merge4"></a>

# %% [markdown]
# ### Merge de olist_sellers_dataset et olist_geolocation_dataset

# %%
df_olist_sellers
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...                                ...                     ...
# 3090  98dddbc4601dd4443ca174359b237166                   87111
# 3091  f8201cab383e484733266d1906e2fdfa                   88137
# 3092  74871d19219c7d518d0090283e03c137                    4650
# 3093  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 3094  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#             seller_city seller_state
# 0              campinas           SP
# 1            mogi guacu           SP
# 2        rio de janeiro           RJ
# 3             sao paulo           SP
# 4     braganca paulista           SP
# ...                 ...          ...
# 3090            sarandi           PR
# 3091            palhoca           SC
# 3092          sao paulo           SP
# 3093            pelotas           RS
# 3094            taubate           SP
#
# [3095 rows x 4 columns]

# %%
df_olist_sellers_geo_agg = df_olist_sellers.merge(df_geo_agg, how='left', left_on='seller_zip_code_prefix', right_on='geolocation_zip_code_prefix')

# %%
# nombre de vendeurs avec l'information sur la géolocalisation manquante
df_olist_sellers_geo_agg['geolocation_lat'].isna().sum()
# Out:
# 7

# %%
# index des lignes geolocation_lat nulles
index_sellers_geona = df_olist_sellers_geo_agg[df_olist_sellers_geo_agg['geolocation_lat'].isna()].index

# %%
index_sellers_geona
# Out:
# Int64Index([473, 791, 1672, 1931, 2182, 2986, 3028], dtype='int64')

# %%
df_sellers_geona = df_olist_sellers_geo_agg[df_olist_sellers_geo_agg['geolocation_lat'].isna()]

# %%
df_sellers_geona_pre_merge = df_sellers_geona.copy()

# %%
df_sellers_geona_pre_merge['old_index'] = df_sellers_geona_pre_merge.index

# %%
# remplissage des valeurs de géolocalisation manquantes en fonction de coordonnées associées aux noms des villes
df_sellers_geofilledna = df_sellers_geona_pre_merge.merge(df_geofornan_agg, how='left', left_on='seller_city', right_on='geolocation_city')

# %%
df_sellers_geofilledna.drop(['geolocation_lat_x','geolocation_lng_x','geolocation_city_x','geolocation_state_x', 'geolocation_city_y', 'geolocation_state_y'], axis=1, inplace=True)

# %%
df_sellers_geofilledna
# Out:
#                           seller_id  seller_zip_code_prefix      seller_city  \
# 0  5962468f885ea01a1b6a97a218797b0a                   82040         curitiba
# 1  2aafae69bf4c41fbd94053d9413e87ee                   91901     porto alegre
# 2  2a50b7ee5aebecc6fd0ff9784a4747d6                   72580         brasilia
# 3  2e90cb1677d35cfe24eef47d441b7c87                    2285        sao paulo
# 4  0b3f27369a4d8df98f7eb91077e438ac                    7412            aruja
# 5  42bde9fef835393bb8a8849cb6b7f245                   71551         brasilia
# 6  870d0118f7a9d85960f29ad89d5d989a                   37708  pocos de caldas
#
#   seller_state  geolocation_zip_code_prefix  old_index  geolocation_lat_y  \
# 0           PR                          NaN        473         -25.449140
# 1           RS                          NaN        791         -30.037884
# 2           DF                          NaN       1672         -15.820008
# 3           SP                          NaN       1931         -23.562440
# 4           SP                          NaN       2182         -23.400984
# 5           DF                          NaN       2986         -15.820008
# 6           MG                          NaN       3028         -21.792327
#
#    geolocation_lng_y
# 0         -49.271910
# 1         -51.193383
# 2         -47.979953
# 3         -46.645713
# 4         -46.321737
# 5         -47.979953
# 6         -46.564103

# %%
df_sellers_geofilledna.rename(columns={"geolocation_lat_y": "geolocation_lat",
                                          "geolocation_lng_y": "geolocation_lng"}, inplace = True)

# %%
df_sellers_geofilledna.set_index(df_sellers_geofilledna['old_index'], inplace=True)

# %%
df_sellers_geofilledna
# Out:
#                                   seller_id  seller_zip_code_prefix  \
# old_index
# 473        5962468f885ea01a1b6a97a218797b0a                   82040
# 791        2aafae69bf4c41fbd94053d9413e87ee                   91901
# 1672       2a50b7ee5aebecc6fd0ff9784a4747d6                   72580
# 1931       2e90cb1677d35cfe24eef47d441b7c87                    2285
# 2182       0b3f27369a4d8df98f7eb91077e438ac                    7412
# 2986       42bde9fef835393bb8a8849cb6b7f245                   71551
# 3028       870d0118f7a9d85960f29ad89d5d989a                   37708
#
#                seller_city seller_state  geolocation_zip_code_prefix  \
# old_index
# 473               curitiba           PR                          NaN
# 791           porto alegre           RS                          NaN
# 1672              brasilia           DF                          NaN
# 1931             sao paulo           SP                          NaN
# 2182                 aruja           SP                          NaN
# 2986              brasilia           DF                          NaN
# 3028       pocos de caldas           MG                          NaN
#
#            old_index  geolocation_lat  geolocation_lng
# old_index
# 473              473       -25.449140       -49.271910
# 791              791       -30.037884       -51.193383
# 1672            1672       -15.820008       -47.979953
# 1931            1931       -23.562440       -46.645713
# 2182            2182       -23.400984       -46.321737
# 2986            2986       -15.820008       -47.979953
# 3028            3028       -21.792327       -46.564103

# %%
df_olist_sellers_geo_agg.loc[index_sellers_geona, 'geolocation_lat'] = df_sellers_geofilledna['geolocation_lat']

# %%
df_olist_sellers_geo_agg[df_olist_sellers_geo_agg['geolocation_lng'].isna()]
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 473   5962468f885ea01a1b6a97a218797b0a                   82040
# 791   2aafae69bf4c41fbd94053d9413e87ee                   91901
# 1672  2a50b7ee5aebecc6fd0ff9784a4747d6                   72580
# 1931  2e90cb1677d35cfe24eef47d441b7c87                    2285
# 2182  0b3f27369a4d8df98f7eb91077e438ac                    7412
# 2986  42bde9fef835393bb8a8849cb6b7f245                   71551
# 3028  870d0118f7a9d85960f29ad89d5d989a                   37708
#
#           seller_city seller_state  geolocation_zip_code_prefix  \
# 473          curitiba           PR                          NaN
# 791      porto alegre           RS                          NaN
# 1672         brasilia           DF                          NaN
# 1931        sao paulo           SP                          NaN
# 2182            aruja           SP                          NaN
# 2986         brasilia           DF                          NaN
# 3028  pocos de caldas           MG                          NaN
#
#       geolocation_lat  geolocation_lng geolocation_city geolocation_state
# 473        -25.449140              NaN              NaN               NaN
# 791        -30.037884              NaN              NaN               NaN
# 1672       -15.820008              NaN              NaN               NaN
# 1931       -23.562440              NaN              NaN               NaN
# 2182       -23.400984              NaN              NaN               NaN
# 2986       -15.820008              NaN              NaN               NaN
# 3028       -21.792327              NaN              NaN               NaN

# %%
df_olist_sellers_geo_agg.loc[index_sellers_geona, 'geolocation_lng'] = df_sellers_geofilledna['geolocation_lng']

# %%
df_olist_sellers_geo_agg.isna().sum()
# Out:
# seller_id                      0
# seller_zip_code_prefix         0
# seller_city                    0
# seller_state                   0
# geolocation_zip_code_prefix    7
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               7
# geolocation_state              7
# dtype: int64

# %%
df_olist_sellers_geo_agg.drop(['geolocation_zip_code_prefix', 'geolocation_city', 'geolocation_state'], axis=1, inplace=True)

# %%
df_olist_sellers_geo_agg.rename(columns={"geolocation_lat": "seller_lat",
                                          "geolocation_lng": "seller_lng"}, inplace = True)

# %%
df_olist_sellers_geo = df_olist_sellers_geo_agg.copy()

# %%
df_olist_sellers_geo.duplicated().sum()
# Out:
# 0

# %%
df_olist_sellers_geo.isna().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# seller_lat                0
# seller_lng                0
# dtype: int64

# %%
df_olist_sellers_geo
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...                                ...                     ...
# 3090  98dddbc4601dd4443ca174359b237166                   87111
# 3091  f8201cab383e484733266d1906e2fdfa                   88137
# 3092  74871d19219c7d518d0090283e03c137                    4650
# 3093  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 3094  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#             seller_city seller_state  seller_lat  seller_lng
# 0              campinas           SP  -22.893863  -47.062006
# 1            mogi guacu           SP  -22.382869  -46.947992
# 2        rio de janeiro           RJ  -22.910174  -43.176775
# 3             sao paulo           SP  -23.656991  -46.612490
# 4     braganca paulista           SP  -22.963763  -46.534676
# ...                 ...          ...         ...         ...
# 3090            sarandi           PR  -23.448591  -51.869229
# 3091            palhoca           SC  -27.626905  -48.674389
# 3092          sao paulo           SP  -23.657622  -46.677126
# 3093            pelotas           RS  -31.751451  -52.323078
# 3094            taubate           SP  -23.011269  -45.585565
#
# [3095 rows x 6 columns]

# %% [markdown]
# ![Le schéma des données](scheme_etape_4.png)

# %% [markdown]
# # Etape 5 de merge <a class="anchor" id="merge5"></a>

# %% [markdown]
# ### merge de *df_orders_cust_geo_orderitems* et *df_olist_sellers_geo*

# %%
# seller_id
df_orders_cust_orderitems_sellers_geo = df_orders_cust_geo_orderitems.merge(df_olist_sellers_geo, how='left', on='seller_id')

# %%
df_orders_cust_orderitems_sellers_geo.shape
# Out:
# (113425, 25)

# %%
df_orders_cust_orderitems_sellers_geo.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 161
# order_delivered_carrier_date     1968
# order_delivered_customer_date    3229
# order_estimated_delivery_date       0
# customer_unique_id                  0
# customer_zip_code_prefix            0
# customer_city                       0
# customer_state                      0
# customer_lat                        0
# customer_lng                        0
# order_item_id                     775
# product_id                        775
# seller_id                         775
# shipping_limit_date               775
# price                             775
# freight_value                     775
# seller_zip_code_prefix            775
# seller_city                       775
# seller_state                      775
# seller_lat                        775
# seller_lng                        775
# dtype: int64

# %% [markdown]
# ![Le schéma des données](scheme_etape_5.png)

# %% [markdown]
# # Etape 6 de merge <a class="anchor" id="merge6"></a>

# %% [markdown]
# ### merge de *df_olist_products* avec *df_product_category_name_translation*

# %%
df_olist_products.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
df_olist_products['product_category_name'].nunique()
# Out:
# 73

# %%
df_product_category_name_translation.shape
# Out:
# (71, 2)

# %%
df_product_category_name_translation.isna().sum()
# Out:
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %%
df_olist_products_product_category_name_translation = df_olist_products.merge(df_product_category_name_translation, how='left', on='product_category_name')

# %%
df_olist_products_product_category_name_translation[df_olist_products_product_category_name_translation['product_category_name'].notna() & df_olist_products_product_category_name_translation['product_category_name_english'].isna()]
# Out:
#                              product_id  \
# 1628   0105b5323d24fc655f73052694dbbb3a
# 5821   6fd83eb3e0799b775e4f946bd66657c0
# 7325   5d923ead886c44b86845f69e50520c3e
# 7478   6727051471a0fc4a0e7737b57bff2549
# 8819   bed164d9d628cf0593003389c535c6e0
# 11039  1220978a08a6b29a202bc015b18250e9
# 14266  ae62bb0f95af63d64eae5f93dddea8d3
# 16182  1954739d84629e7323a4295812a3e0ec
# 16930  dbe520fb381ad695a7e1f2807d20c765
# 17800  c7a3f1a7f9eef146cc499368b578b884
# 18610  7afdd65f79f63819ff5bee328843fa37
# 26890  a4756663d007b0cd1af865754d08d968
# 29919  cb9d764f38ee4d0c00af64d5c388f837
#
#                                product_category_name  product_name_lenght  \
# 1628                                        pc_gamer                 59.0
# 5821   portateis_cozinha_e_preparadores_de_alimentos                 52.0
# 7325   portateis_cozinha_e_preparadores_de_alimentos                 58.0
# 7478                                        pc_gamer                 60.0
# 8819   portateis_cozinha_e_preparadores_de_alimentos                 54.0
# 11039  portateis_cozinha_e_preparadores_de_alimentos                 46.0
# 14266  portateis_cozinha_e_preparadores_de_alimentos                 59.0
# 16182  portateis_cozinha_e_preparadores_de_alimentos                 58.0
# 16930                                       pc_gamer                 60.0
# 17800  portateis_cozinha_e_preparadores_de_alimentos                 52.0
# 18610  portateis_cozinha_e_preparadores_de_alimentos                 48.0
# 26890  portateis_cozinha_e_preparadores_de_alimentos                 60.0
# 29919  portateis_cozinha_e_preparadores_de_alimentos                 57.0
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# 1628                        621.0                 4.0            2839.0
# 5821                        280.0                 1.0            1200.0
# 7325                        284.0                 1.0            1200.0
# 7478                       1532.0                 3.0             650.0
# 8819                        382.0                 2.0             850.0
# 11039                       280.0                 1.0            1200.0
# 14266                       927.0                 1.0           10600.0
# 16182                       792.0                 4.0             750.0
# 16930                       840.0                 6.0             800.0
# 17800                      1372.0                 5.0            7350.0
# 18610                       305.0                 1.0             750.0
# 26890                      1304.0                 4.0             650.0
# 29919                       306.0                 1.0             625.0
#
#        product_length_cm  product_height_cm  product_width_cm  \
# 1628                19.0               16.0              18.0
# 5821                25.0               33.0              25.0
# 7325                25.0               33.0              25.0
# 7478                16.0               22.0              20.0
# 8819                30.0               21.0              22.0
# 11039               25.0               33.0              25.0
# 14266               40.0               20.0              38.0
# 16182               30.0               30.0              30.0
# 16930               18.0               22.0              22.0
# 17800               40.0               30.0              23.0
# 18610               20.0               20.0              20.0
# 26890               22.0                6.0              14.0
# 29919               28.0               27.0              24.0
#
#       product_category_name_english
# 1628                            NaN
# 5821                            NaN
# 7325                            NaN
# 7478                            NaN
# 8819                            NaN
# 11039                           NaN
# 14266                           NaN
# 16182                           NaN
# 16930                           NaN
# 17800                           NaN
# 18610                           NaN
# 26890                           NaN
# 29919                           NaN

# %% [markdown]
# ## Imputation d'une traduction manqaunte <a class="anchor" id="trad_prod"></a>

# %%
# portateis_cozinha_e_preparadores_de_alimentos = portable_kitchen_and_food_preparers
df_olist_products_product_category_name_translation.loc[df_olist_products_product_category_name_translation[df_olist_products_product_category_name_translation['product_category_name'] == 'portateis_cozinha_e_preparadores_de_alimentos'].index, 'product_category_name_english'] = 'portable_kitchen_and_food_preparers'

# %%
df_olist_products_product_category_name_translation[df_olist_products_product_category_name_translation['product_category_name'] == 'portateis_cozinha_e_preparadores_de_alimentos']
# Out:
#                              product_id  \
# 5821   6fd83eb3e0799b775e4f946bd66657c0
# 7325   5d923ead886c44b86845f69e50520c3e
# 8819   bed164d9d628cf0593003389c535c6e0
# 11039  1220978a08a6b29a202bc015b18250e9
# 14266  ae62bb0f95af63d64eae5f93dddea8d3
# 16182  1954739d84629e7323a4295812a3e0ec
# 17800  c7a3f1a7f9eef146cc499368b578b884
# 18610  7afdd65f79f63819ff5bee328843fa37
# 26890  a4756663d007b0cd1af865754d08d968
# 29919  cb9d764f38ee4d0c00af64d5c388f837
#
#                                product_category_name  product_name_lenght  \
# 5821   portateis_cozinha_e_preparadores_de_alimentos                 52.0
# 7325   portateis_cozinha_e_preparadores_de_alimentos                 58.0
# 8819   portateis_cozinha_e_preparadores_de_alimentos                 54.0
# 11039  portateis_cozinha_e_preparadores_de_alimentos                 46.0
# 14266  portateis_cozinha_e_preparadores_de_alimentos                 59.0
# 16182  portateis_cozinha_e_preparadores_de_alimentos                 58.0
# 17800  portateis_cozinha_e_preparadores_de_alimentos                 52.0
# 18610  portateis_cozinha_e_preparadores_de_alimentos                 48.0
# 26890  portateis_cozinha_e_preparadores_de_alimentos                 60.0
# 29919  portateis_cozinha_e_preparadores_de_alimentos                 57.0
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# 5821                        280.0                 1.0            1200.0
# 7325                        284.0                 1.0            1200.0
# 8819                        382.0                 2.0             850.0
# 11039                       280.0                 1.0            1200.0
# 14266                       927.0                 1.0           10600.0
# 16182                       792.0                 4.0             750.0
# 17800                      1372.0                 5.0            7350.0
# 18610                       305.0                 1.0             750.0
# 26890                      1304.0                 4.0             650.0
# 29919                       306.0                 1.0             625.0
#
#        product_length_cm  product_height_cm  product_width_cm  \
# 5821                25.0               33.0              25.0
# 7325                25.0               33.0              25.0
# 8819                30.0               21.0              22.0
# 11039               25.0               33.0              25.0
# 14266               40.0               20.0              38.0
# 16182               30.0               30.0              30.0
# 17800               40.0               30.0              23.0
# 18610               20.0               20.0              20.0
# 26890               22.0                6.0              14.0
# 29919               28.0               27.0              24.0
#
#              product_category_name_english
# 5821   portable_kitchen_and_food_preparers
# 7325   portable_kitchen_and_food_preparers
# 8819   portable_kitchen_and_food_preparers
# 11039  portable_kitchen_and_food_preparers
# 14266  portable_kitchen_and_food_preparers
# 16182  portable_kitchen_and_food_preparers
# 17800  portable_kitchen_and_food_preparers
# 18610  portable_kitchen_and_food_preparers
# 26890  portable_kitchen_and_food_preparers
# 29919  portable_kitchen_and_food_preparers

# %%
df_olist_products_product_category_name_translation.loc[df_olist_products_product_category_name_translation[df_olist_products_product_category_name_translation['product_category_name'] == 'pc_gamer'].index, 'product_category_name_english'] = 'pc_gamer'

# %%
df_olist_products_product_category_name_translation[df_olist_products_product_category_name_translation['product_category_name'] == 'pc_gamer']
# Out:
#                              product_id product_category_name  \
# 1628   0105b5323d24fc655f73052694dbbb3a              pc_gamer
# 7478   6727051471a0fc4a0e7737b57bff2549              pc_gamer
# 16930  dbe520fb381ad695a7e1f2807d20c765              pc_gamer
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 1628                  59.0                       621.0                 4.0
# 7478                  60.0                      1532.0                 3.0
# 16930                 60.0                       840.0                 6.0
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 1628             2839.0               19.0               16.0
# 7478              650.0               16.0               22.0
# 16930             800.0               18.0               22.0
#
#        product_width_cm product_category_name_english
# 1628               18.0                      pc_gamer
# 7478               20.0                      pc_gamer
# 16930              22.0                      pc_gamer

# %%
df_olist_products_product_category_name_translation.drop(['product_category_name'], axis=1, inplace=True)

# %%
df_olist_products_product_category_name_translation.rename(columns={"product_category_name_english": "product_category_name"}, inplace=True)

# %%
df_olist_products_product_category_name_translation.loc[df_olist_products_product_category_name_translation[df_olist_products_product_category_name_translation['product_category_name'].isna()].index, 'product_category_name'] = 'other'

# %%
df_olist_products_product_category_name_translation[df_olist_products_product_category_name_translation['product_category_name'] == 'other']
# Out:
#                              product_id  product_name_lenght  \
# 105    a41e356c76fab66334f36de622ecbd3a                  NaN
# 128    d8dee61c2034d6d075997acef1870e9b                  NaN
# 145    56139431d72cd51f19eb9f7dae4d1617                  NaN
# 154    46b48281eb6d663ced748f324108c733                  NaN
# 197    5fb61f482620cb672f5e586bb132eae9                  NaN
# ...                                 ...                  ...
# 32515  b0a0c5dd78e644373b199380612c350a                  NaN
# 32589  10dbe0fbaa2c505123c17fdc34a63c56                  NaN
# 32616  bd2ada37b58ae94cc838b9c0569fecd8                  NaN
# 32772  fa51e914046aab32764c41356b9d4ea4                  NaN
# 32852  c4ceee876c82b8328e9c293fa0e1989b                  NaN
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# 105                           NaN                 NaN             650.0
# 128                           NaN                 NaN             300.0
# 145                           NaN                 NaN             200.0
# 154                           NaN                 NaN           18500.0
# 197                           NaN                 NaN             300.0
# ...                           ...                 ...               ...
# 32515                         NaN                 NaN            1800.0
# 32589                         NaN                 NaN             800.0
# 32616                         NaN                 NaN             200.0
# 32772                         NaN                 NaN            1300.0
# 32852                         NaN                 NaN             700.0
#
#        product_length_cm  product_height_cm  product_width_cm  \
# 105                 17.0               14.0              12.0
# 128                 16.0                7.0              20.0
# 145                 20.0               20.0              20.0
# 154                 41.0               30.0              41.0
# 197                 35.0                7.0              12.0
# ...                  ...                ...               ...
# 32515               30.0               20.0              70.0
# 32589               30.0               10.0              23.0
# 32616               21.0                8.0              16.0
# 32772               45.0               16.0              45.0
# 32852               28.0                3.0              43.0
#
#       product_category_name
# 105                   other
# 128                   other
# 145                   other
# 154                   other
# 197                   other
# ...                     ...
# 32515                 other
# 32589                 other
# 32616                 other
# 32772                 other
# 32852                 other
#
# [610 rows x 9 columns]

# %%
df_olist_products_product_category_name_translation.isna().sum()
# Out:
# product_id                      0
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# product_category_name           0
# dtype: int64

# %%
df_olist_products_category_name_en = df_olist_products_product_category_name_translation.copy()

# %% [markdown]
# # Etape 7 de merge <a class="anchor" id="merge7"></a>

# %% [markdown]
# ### merge de *df_orders_cust_orderitems_sellers_geo* avec *df_olist_products_category_name_en*

# %%
df_orders_cust_orderitems_sellers_geo_products_en = df_orders_cust_orderitems_sellers_geo.merge(df_olist_products_category_name_en, how='left', on='product_id')

# %%
len(df_orders_cust_orderitems_sellers_geo_products_en)
# Out:
# 113425

# %%
df_orders_cust_orderitems_sellers_geo_products_en.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 161
# order_delivered_carrier_date     1968
# order_delivered_customer_date    3229
# order_estimated_delivery_date       0
# customer_unique_id                  0
# customer_zip_code_prefix            0
# customer_city                       0
# customer_state                      0
# customer_lat                        0
# customer_lng                        0
# order_item_id                     775
# product_id                        775
# seller_id                         775
# shipping_limit_date               775
# price                             775
# freight_value                     775
# seller_zip_code_prefix            775
# seller_city                       775
# seller_state                      775
# seller_lat                        775
# seller_lng                        775
# product_name_lenght              2378
# product_description_lenght       2378
# product_photos_qty               2378
# product_weight_g                  793
# product_length_cm                 793
# product_height_cm                 793
# product_width_cm                  793
# product_category_name             775
# dtype: int64

# %% [markdown]
# ![Le schéma des données](scheme_etape_7.png)

# %% [markdown]
# # Etape 8 de merge <a class="anchor" id="merge8"></a>

# %% [markdown]
# ###  merge de *df_orders_cust_orderitems_sellers_geo_products_en* et *df_olist_order_payments*

# %%
df_orders_cust_orderitems_sellers_geo_products_en_order_payments = df_orders_cust_orderitems_sellers_geo_products_en.merge(df_olist_order_payments, how='left', on='order_id')

# %%
df_orders_cust_orderitems_sellers_geo_products_en_order_payments.shape
# Out:
# (118434, 37)

# %%
df_orders_cust_orderitems_sellers_geo_products_en_order_payments.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 176
# order_delivered_carrier_date     2074
# order_delivered_customer_date    3397
# order_estimated_delivery_date       0
# customer_unique_id                  0
# customer_zip_code_prefix            0
# customer_city                       0
# customer_state                      0
# customer_lat                        0
# customer_lng                        0
# order_item_id                     830
# product_id                        830
# seller_id                         830
# shipping_limit_date               830
# price                             830
# freight_value                     830
# seller_zip_code_prefix            830
# seller_city                       830
# seller_state                      830
# seller_lat                        830
# seller_lng                        830
# product_name_lenght              2528
# product_description_lenght       2528
# product_photos_qty               2528
# product_weight_g                  850
# product_length_cm                 850
# product_height_cm                 850
# product_width_cm                  850
# product_category_name             830
# payment_sequential                  3
# payment_type                        3
# payment_installments                3
# payment_value                       3
# dtype: int64

# %% [markdown]
# # Etape 9 de merge <a class="anchor" id="merge9"></a>

# %% [markdown]
# ### merge de *df_orders_cust_orderitems_sellers_geo_products_en_order_payments* et *df_olist_order_reviews_dataset*

# %%
df_olist_total = df_orders_cust_orderitems_sellers_geo_products_en_order_payments.merge(df_olist_order_reviews_dataset, how='left', on='order_id')

# %%
df_olist_total.shape
# Out:
# (119151, 42)

# %%
df_olist_total.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 177
# order_delivered_carrier_date     2086
# order_delivered_customer_date    3421
# order_estimated_delivery_date       0
# customer_unique_id                  0
# customer_zip_code_prefix            0
# customer_city                       0
# customer_state                      0
# customer_lat                        0
# customer_lng                        0
# order_item_id                     833
# product_id                        833
# seller_id                         833
# shipping_limit_date               833
# price                             833
# freight_value                     833
# seller_zip_code_prefix            833
# seller_city                       833
# seller_state                      833
# seller_lat                        833
# seller_lng                        833
# product_name_lenght              2542
# product_description_lenght       2542
# product_photos_qty               2542
# product_weight_g                  853
# product_length_cm                 853
# product_height_cm                 853
# product_width_cm                  853
# product_category_name             833
# payment_sequential                  3
# payment_type                        3
# payment_installments                3
# payment_value                       3
# review_id                           0
# review_score                        0
# review_creation_date                0
# review_answer_timestamp             0
# contain_message                     0
# dtype: int64

# %%
# Sauvegarde de la df dans un fichier
df_olist_total.to_csv('df_olist_total.csv', encoding='utf-8', index=False)
